# %% [markdown]
# Right now just download mapping table for (same for IS and CF):
# - Non-blank `Final account name` and
# - Non-N/A `Lookup on vstock BS nonfin`
#
# See https://docs.google.com/spreadsheets/d/1iiR5EZk3MVRvdNpcJJWF41Yj2yTtVgSQAmxWeNh0YTk/

# %%
import pandas as pd
import numpy as np
import json
import glob
import traceback
from functions.fad_crawl.helpers.processingData import simplifyText

# %%
BS_sheet = "vstock+VAS BS"
IS_sheet = "vstock+VAS IS"
CF_D_sheet = "vstock+VAS CF Direct"
CF_IND_sheet = "vstock+VAS CF Indirect"
mapping_all = pd.read_excel("functions/schema/mapping_table.xlsx", sheet_name=[BS_sheet,IS_sheet,CF_D_sheet,CF_IND_sheet])

# %%
### Read XLSX mapping file, use Pandas to convert to JSON
mapping_BS_filtered = mapping_all[BS_sheet][(mapping_all[BS_sheet]['Final account name'].notnull()) & (mapping_all[BS_sheet]['Lookup on vstock BS nonfin'].notnull())]
mapping_IS_filtered = mapping_all[IS_sheet][(mapping_all[IS_sheet]['Final account name'].notnull()) & (mapping_all[IS_sheet]['Lookup on vstock IS nonfin'].notnull())]
mapping_CF_D_filtered = mapping_all[CF_D_sheet][(mapping_all[CF_D_sheet]['Final account name'].notnull()) & (mapping_all[CF_D_sheet]['Lookup on vstock CF Direct nonfin'].notnull())]
mapping_CF_IND_filtered = mapping_all[CF_IND_sheet][(mapping_all[CF_IND_sheet]['Final account name'].notnull()) & (mapping_all[CF_IND_sheet]['Lookup on vstock CF Indirect nonfin'].notnull())]

# %%
### Create mapping dictionaries
mapping_BS_dict = dict(zip(mapping_BS_filtered['Lookup on vstock BS nonfin'], mapping_BS_filtered['Final account name']))
mapping_IS_dict = dict(zip(mapping_IS_filtered['Lookup on vstock IS nonfin'], mapping_IS_filtered['Final account name']))
mapping_CF_D_dict = dict(zip(mapping_CF_D_filtered['Lookup on vstock CF Direct nonfin'], mapping_CF_D_filtered['Final account name']))
mapping_CF_IND_dict = dict(zip(mapping_CF_IND_filtered['Lookup on vstock CF Indirect nonfin'], mapping_CF_IND_filtered['Final account name']))


### The mapping dict is constructed manually based on the structure of the lookup_dict_all_nonfin file
mapping_dict_all = {
    "CDKT": {
        "Balance Sheet": mapping_BS_dict
    },
    "KQKD": {
        "Income Statement": mapping_IS_dict
    },
    "LC": {
        "CashFlow Direct" : mapping_CF_D_dict,
        "CashFlow Indirect": mapping_CF_IND_dict
    }
}

with open("functions/schema/mapping_dict_all_nonfin.json", "w") as writefile:
    json.dump(mapping_dict_all, writefile, ensure_ascii=False, indent=4)

# %%
### Load lookup all accounts nonfin file
with open("functions/schema/lookup_dict_all_nonfin.json", "r") as jsonfile:
    lookup = json.load(jsonfile)
lookup
# Out:
# {'CDKT': {'Balance Sheet': {'2995': {'ID': 1,
#     'ReportNormID': 2995,
#     'Name': 'TÀI SẢN ',
#     'NameEn': 'ASSETS',
#     'NameMobile': 'TÀI SẢN ',
#     'NameMobileEn': 'ASSETS',
#     'CssStyle': 'MaxB',
#     'Padding': 'Padding1',
#     'ParentReportNormID': 2995,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 0,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3000': {'ID': 2,
#     'ReportNormID': 3000,
#     'Name': 'A. TÀI SẢN NGẮN HẠN',
#     'NameEn': 'A. SHORT-TERM ASSETS',
#     'NameMobile': 'A. TÀI SẢN NGẮN HẠN',
#     'NameMobileEn': 'A. SHORT-TERM ASSETS',
#     'CssStyle': 'LargeB',
#     'Padding': 'Padding1',
#     'ParentReportNormID': 2996,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 25,
#     'Levels': 1,
#     'Value1': 29366.0,
#     'Value2': 23386.0,
#     'Value3': 16805.0,
#     'Value4': 21290.0,
#     'Vl': None,
#     'IsShowData': True},
#    '3003': {'ID': 3,
#     'ReportNormID': 3003,
#     'Name': 'I. Tiền và các khoản tương đương tiền',
#     'NameEn': 'I. Cash and cash equivalents',
#     'NameMobile': 'I. Tiền và các khoản tương đương tiền',
#     'NameMobileEn': 'I. Cash and cash equivalents',
#     'CssStyle': 'NormalB',
#     'Padding': 'Padding2',
#     'ParentReportNormID': 3000,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 2,
#     'Levels': 2,
#     'Value1': 258.0,
#     'Value2': 2181.0,
#     'Value3': 1307.0,
#     'Value4': 8045.0,
#     'Vl': None,
#     'IsShowData': True},
#    '3018': {'ID': 4,
#     'ReportNormID': 3018,
#     'Name': '1. Tiền',
#     'NameEn': '1. Cash',
#     'NameMobile': '1. Tiền',
#     'NameMobileEn': '1. Cash',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3003,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': 258.0,
#     'Value2': 2181.0,
#     'Value3': 1307.0,
#     'Value4': 8045.0,
#     'Vl': None,
#     'IsShowData': True},
#    '3019': {'ID': 5,
#     'ReportNormID': 3019,
#     'Name': '2. Các khoản tương đương tiền',
#     'NameEn': '2. Cash equivalents',
#     'NameMobile': '2. Các khoản tương đương tiền',
#     'NameMobileEn': '2. Cash equivalents',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3003,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3004': {'ID': 6,
#     'ReportNormID': 3004,
#     'Name': 'II.  Đầu tư tài chính ngắn hạn',
#     'NameEn': 'II.  Short-term financial investments',
#     'NameMobile': 'II.  Đầu tư tài chính ngắn hạn',
#     'NameMobileEn': 'II.  Short-term financial investments',
#     'CssStyle': 'NormalB',
#     'Padding': 'Padding2',
#     'ParentReportNormID': 3000,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 3,
#     'Levels': 2,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3020': {'ID': 7,
#     'ReportNormID': 3020,
#     'Name': '1. Chứng khoán kinh doanh',
#     'NameEn': '1. Available for sale securities',
#     'NameMobile': '1. Chứng khoán kinh doanh',
#     'NameMobileEn': '1. Available for sale securities',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3004,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3021': {'ID': 8,
#     'ReportNormID': 3021,
#     'Name': '2. Dự phòng giảm giá chứng khoán kinh doanh (*)',
#     'NameEn': '2. Provision for diminution in value of available for sale securities (*)',
#     'NameMobile': '2. Dự phòng giảm giá chứng khoán kinh doanh (*)',
#     'NameMobileEn': '2. Provision for diminution in value of available for sale securities (*)',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3004,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '5297': {'ID': 9,
#     'ReportNormID': 5297,
#     'Name': '3. Đầu tư nắm giữ đến ngày đáo hạn',
#     'NameEn': '3. Held to maturity investments',
#     'NameMobile': '3. Đầu tư nắm giữ đến ngày đáo hạn',
#     'NameMobileEn': '3. Held to maturity investments',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3004,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3005': {'ID': 10,
#     'ReportNormID': 3005,
#     'Name': 'III. Các khoản phải thu ngắn hạn',
#     'NameEn': 'III. Short-term receivables',
#     'NameMobile': 'III. Các khoản phải thu ngắn hạn',
#     'NameMobileEn': 'III. Short-term receivables',
#     'CssStyle': 'NormalB',
#     'Padding': 'Padding2',
#     'ParentReportNormID': 3000,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 8,
#     'Levels': 2,
#     'Value1': 3847.0,
#     'Value2': 561.0,
#     'Value3': 9301.0,
#     'Value4': 13062.0,
#     'Vl': None,
#     'IsShowData': True},
#    '3022': {'ID': 11,
#     'ReportNormID': 3022,
#     'Name': '1. Phải thu ngắn hạn của khách hàng',
#     'NameEn': '1. Short-term trade accounts receivable',
#     'NameMobile': '1. Phải thu ngắn hạn của khách hàng',
#     'NameMobileEn': '1. Short-term trade accounts receivable',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3005,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': 3847.0,
#     'Value2': 560.0,
#     'Value3': 9275.0,
#     'Value4': 12844.0,
#     'Vl': None,
#     'IsShowData': True},
#    '3023': {'ID': 12,
#     'ReportNormID': 3023,
#     'Name': '2. Trả trước cho người bán ngắn hạn',
#     'NameEn': '2. Short-term prepayments to suppliers  ',
#     'NameMobile': '2. Trả trước cho người bán ngắn hạn',
#     'NameMobileEn': '2. Short-term prepayments to suppliers  ',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3005,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': 25.0,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3024': {'ID': 13,
#     'ReportNormID': 3024,
#     'Name': '3. Phải thu nội bộ ngắn hạn',
#     'NameEn': '3. Short-term inter-company receivables',
#     'NameMobile': '3. Phải thu nội bộ ngắn hạn',
#     'NameMobileEn': '3. Short-term inter-company receivables',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3005,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3025': {'ID': 14,
#     'ReportNormID': 3025,
#     'Name': '4. Phải thu theo tiến độ kế hoạch hợp đồng xây dựng',
#     'NameEn': '4. Construction contract progress receipts due from customers',
#     'NameMobile': '4. Phải thu theo tiến độ kế hoạch hợp đồng xây dựng',
#     'NameMobileEn': '4. Construction contract progress receipts due from customers',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3005,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '5300': {'ID': 15,
#     'ReportNormID': 5300,
#     'Name': '5. Phải thu về cho vay ngắn hạn',
#     'NameEn': '5. Short-term loan receivables',
#     'NameMobile': '5. Phải thu về cho vay ngắn hạn',
#     'NameMobileEn': '5. Short-term loan receivables',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3005,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3026': {'ID': 16,
#     'ReportNormID': 3026,
#     'Name': '6. Phải thu ngắn hạn khác',
#     'NameEn': '6. Other short-term receivables ',
#     'NameMobile': '6. Phải thu ngắn hạn khác',
#     'NameMobileEn': '6. Other short-term receivables ',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3005,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': 1.0,
#     'Value3': 2.0,
#     'Value4': 218.0,
#     'Vl': None,
#     'IsShowData': True},
#    '3079': {'ID': 17,
#     'ReportNormID': 3079,
#     'Name': '7. Dự phòng phải thu ngắn hạn khó đòi (*)',
#     'NameEn': '7. Provision for short-term doubtful debts (*)',
#     'NameMobile': '7. Dự phòng phải thu ngắn hạn khó đòi (*)',
#     'NameMobileEn': '7. Provision for short-term doubtful debts (*)',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3005,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '5299': {'ID': 18,
#     'ReportNormID': 5299,
#     'Name': '8. Tài sản thiếu chờ xử lý',
#     'NameEn': '8. Assets awaiting resolution',
#     'NameMobile': '8. Tài sản thiếu chờ xử lý',
#     'NameMobileEn': '8. Assets awaiting resolution',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3005,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3006': {'ID': 19,
#     'ReportNormID': 3006,
#     'Name': 'IV. Hàng tồn kho',
#     'NameEn': 'IV. Inventories',
#     'NameMobile': 'IV. Hàng tồn kho',
#     'NameMobileEn': 'IV. Inventories',
#     'CssStyle': 'NormalB',
#     'Padding': 'Padding2',
#     'ParentReportNormID': 3000,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 2,
#     'Levels': 2,
#     'Value1': 24367.0,
#     'Value2': 19796.0,
#     'Value3': 3233.0,
#     'Value4': 32.0,
#     'Vl': None,
#     'IsShowData': True},
#    '3027': {'ID': 20,
#     'ReportNormID': 3027,
#     'Name': '1. Hàng tồn kho',
#     'NameEn': '1. Inventories',
#     'NameMobile': '1. Hàng tồn kho',
#     'NameMobileEn': '1. Inventories',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3006,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': 24367.0,
#     'Value2': 19796.0,
#     'Value3': 3233.0,
#     'Value4': 32.0,
#     'Vl': None,
#     'IsShowData': True},
#    '3080': {'ID': 21,
#     'ReportNormID': 3080,
#     'Name': '2. Dự phòng giảm giá hàng tồn kho (*)',
#     'NameEn': '2. Provision for decline in value of inventories ',
#     'NameMobile': '2. Dự phòng giảm giá hàng tồn kho (*)',
#     'NameMobileEn': '2. Provision for decline in value of inventories ',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3006,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3007': {'ID': 22,
#     'ReportNormID': 3007,
#     'Name': 'V. Tài sản ngắn hạn khác',
#     'NameEn': 'V. Other short-term assets',
#     'NameMobile': 'V. Tài sản ngắn hạn khác',
#     'NameMobileEn': 'V. Other short-term assets',
#     'CssStyle': 'NormalB',
#     'Padding': 'Padding2',
#     'ParentReportNormID': 3000,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 5,
#     'Levels': 2,
#     'Value1': 894.0,
#     'Value2': 848.0,
#     'Value3': 2964.0,
#     'Value4': 152.0,
#     'Vl': None,
#     'IsShowData': True},
#    '3028': {'ID': 23,
#     'ReportNormID': 3028,
#     'Name': '1. Chi phí trả trước ngắn hạn',
#     'NameEn': '1. Short-term prepayments',
#     'NameMobile': '1. Chi phí trả trước ngắn hạn',
#     'NameMobileEn': '1. Short-term prepayments',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3007,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': 868.0,
#     'Value2': 843.0,
#     'Value3': 2961.0,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3029': {'ID': 24,
#     'ReportNormID': 3029,
#     'Name': '2. Thuế GTGT được khấu trừ',
#     'NameEn': '2. Value added tax to be reclaimed',
#     'NameMobile': '2. Thuế GTGT được khấu trừ',
#     'NameMobileEn': '2. Value added tax to be reclaimed',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3007,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3030': {'ID': 25,
#     'ReportNormID': 3030,
#     'Name': '3. Thuế và các khoản khác phải thu của nhà nước',
#     'NameEn': '3. Taxes and other receivables from state authorities',
#     'NameMobile': '3. Thuế và các khoản khác phải thu của nhà nước',
#     'NameMobileEn': '3. Taxes and other receivables from state authorities',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3007,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': 25.0,
#     'Value2': 5.0,
#     'Value3': 3.0,
#     'Value4': 152.0,
#     'Vl': None,
#     'IsShowData': True},
#    '5270': {'ID': 26,
#     'ReportNormID': 5270,
#     'Name': '4. Giao dịch mua bán lại trái phiếu chính phủ',
#     'NameEn': '4. Government bonds',
#     'NameMobile': '4. Giao dịch mua bán lại trái phiếu chính phủ',
#     'NameMobileEn': '4. Government bonds',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3007,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3031': {'ID': 27,
#     'ReportNormID': 3031,
#     'Name': '5. Tài sản ngắn hạn khác',
#     'NameEn': '5. Other short-term assets',
#     'NameMobile': '5. Tài sản ngắn hạn khác',
#     'NameMobileEn': '5. Other short-term assets',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3007,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3001': {'ID': 28,
#     'ReportNormID': 3001,
#     'Name': 'B. TÀI SẢN DÀI HẠN',
#     'NameEn': 'B. LONG-TERM ASSETS ',
#     'NameMobile': 'B. TÀI SẢN DÀI HẠN',
#     'NameMobileEn': 'B. LONG-TERM ASSETS ',
#     'CssStyle': 'LargeB',
#     'Padding': 'Padding1',
#     'ParentReportNormID': 2996,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 37,
#     'Levels': 1,
#     'Value1': 23288.0,
#     'Value2': 25501.0,
#     'Value3': 21780.0,
#     'Value4': 14491.0,
#     'Vl': None,
#     'IsShowData': True},
#    '3008': {'ID': 29,
#     'ReportNormID': 3008,
#     'Name': 'I. Các khoản phải thu dài hạn',
#     'NameEn': 'I. Long-term receivables',
#     'NameMobile': 'I. Các khoản phải thu dài hạn',
#     'NameMobileEn': 'I. Long-term receivables',
#     'CssStyle': 'NormalB',
#     'Padding': 'Padding2',
#     'ParentReportNormID': 3001,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 7,
#     'Levels': 2,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3032': {'ID': 30,
#     'ReportNormID': 3032,
#     'Name': '1. Phải thu dài hạn của khách hàng',
#     'NameEn': '1. Long-term trade receivables',
#     'NameMobile': '1. Phải thu dài hạn của khách hàng',
#     'NameMobileEn': '1. Long-term trade receivables',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3008,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '5301': {'ID': 31,
#     'ReportNormID': 5301,
#     'Name': '2. Trả trước cho người bán dài hạn',
#     'NameEn': '2. Long-term prepayments to suppliers  ',
#     'NameMobile': '2. Trả trước cho người bán dài hạn',
#     'NameMobileEn': '2. Long-term prepayments to suppliers  ',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3008,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3033': {'ID': 32,
#     'ReportNormID': 3033,
#     'Name': '3. Vốn kinh doanh ở các đơn vị trực thuộc',
#     'NameEn': '3. Capital at inter-company',
#     'NameMobile': '3. Vốn kinh doanh ở các đơn vị trực thuộc',
#     'NameMobileEn': '3. Capital at inter-company',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3008,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3034': {'ID': 33,
#     'ReportNormID': 3034,
#     'Name': '4.  Phải thu nội bộ dài hạn ',
#     'NameEn': '4. Long-term inter-company receivables',
#     'NameMobile': '4.  Phải thu nội bộ dài hạn ',
#     'NameMobileEn': '4. Long-term inter-company receivables',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3008,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '5302': {'ID': 34,
#     'ReportNormID': 5302,
#     'Name': '5. Phải thu về cho vay dài hạn',
#     'NameEn': '5. Long-term loan receivables',
#     'NameMobile': '5. Phải thu về cho vay dài hạn',
#     'NameMobileEn': '5. Long-term loan receivables',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3008,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3081': {'ID': 35,
#     'ReportNormID': 3081,
#     'Name': '6. Phải thu dài hạn khác',
#     'NameEn': '6. Other long-term receivables',
#     'NameMobile': '6. Phải thu dài hạn khác',
#     'NameMobileEn': '6. Other long-term receivables',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3008,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3082': {'ID': 36,
#     'ReportNormID': 3082,
#     'Name': '7. Dự phòng phải thu dài hạn khó đòi (*)',
#     'NameEn': '7. Provision for long-term doubtful debts',
#     'NameMobile': '7. Dự phòng phải thu dài hạn khó đòi (*)',
#     'NameMobileEn': '7. Provision for long-term doubtful debts',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3008,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3009': {'ID': 37,
#     'ReportNormID': 3009,
#     'Name': 'II. Tài sản cố định',
#     'NameEn': 'II. Fixed assets',
#     'NameMobile': 'II. Tài sản cố định',
#     'NameMobileEn': 'II. Fixed assets',
#     'CssStyle': 'NormalB',
#     'Padding': 'Padding2',
#     'ParentReportNormID': 3001,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 9,
#     'Levels': 2,
#     'Value1': 21264.0,
#     'Value2': 21557.0,
#     'Value3': 21492.0,
#     'Value4': 13260.0,
#     'Vl': None,
#     'IsShowData': True},
#    '3035': {'ID': 38,
#     'ReportNormID': 3035,
#     'Name': '1. Tài sản cố định hữu hình',
#     'NameEn': '1. Tangible fixed assets',
#     'NameMobile': '1. Tài sản cố định hữu hình',
#     'NameMobileEn': '1. Tangible fixed assets',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3009,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 2,
#     'Levels': 3,
#     'Value1': 21264.0,
#     'Value2': 21557.0,
#     'Value3': 21492.0,
#     'Value4': 13260.0,
#     'Vl': None,
#     'IsShowData': True},
#    '3083': {'ID': 39,
#     'ReportNormID': 3083,
#     'Name': '      - Nguyên giá',
#     'NameEn': '    - Cost',
#     'NameMobile': '      - Nguyên giá',
#     'NameMobileEn': '    - Cost',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding4',
#     'ParentReportNormID': 3035,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 4,
#     'Value1': 43851.0,
#     'Value2': 40142.0,
#     'Value3': 34741.0,
#     'Value4': 24490.0,
#     'Vl': None,
#     'IsShowData': True},
#    '3084': {'ID': 40,
#     'ReportNormID': 3084,
#     'Name': '      - Giá trị hao mòn lũy kế (*)',
#     'NameEn': '    - Accumulated depreciation',
#     'NameMobile': '      - Giá trị hao mòn lũy kế (*)',
#     'NameMobileEn': '    - Accumulated depreciation',
#     'CssStyle': 'NormalI',
#     'Padding': 'Padding4',
#     'ParentReportNormID': 3035,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 4,
#     'Value1': -22587.0,
#     'Value2': -18584.0,
#     'Value3': -13249.0,
#     'Value4': -11230.0,
#     'Vl': None,
#     'IsShowData': True},
#    '3036': {'ID': 41,
#     'ReportNormID': 3036,
#     'Name': '2. Tài sản cố định thuê tài chính',
#     'NameEn': '2. Financial leased fixed assets',
#     'NameMobile': '2. Tài sản cố định thuê tài chính',
#     'NameMobileEn': '2. Financial leased fixed assets',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3009,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 2,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3085': {'ID': 42,
#     'ReportNormID': 3085,
#     'Name': '      - Nguyên giá',
#     'NameEn': '    - Cost',
#     'NameMobile': '      - Nguyên giá',
#     'NameMobileEn': '    - Cost',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding4',
#     'ParentReportNormID': 3036,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 4,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3086': {'ID': 43,
#     'ReportNormID': 3086,
#     'Name': '      - Giá trị hao mòn lũy kế (*)',
#     'NameEn': '    - Accumulated depreciation',
#     'NameMobile': '      - Giá trị hao mòn lũy kế (*)',
#     'NameMobileEn': '    - Accumulated depreciation',
#     'CssStyle': 'NormalI',
#     'Padding': 'Padding4',
#     'ParentReportNormID': 3036,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 4,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3037': {'ID': 44,
#     'ReportNormID': 3037,
#     'Name': '3. Tài sản cố định vô hình',
#     'NameEn': '3. Intangible fixed assets',
#     'NameMobile': '3. Tài sản cố định vô hình',
#     'NameMobileEn': '3. Intangible fixed assets',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3009,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 2,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3087': {'ID': 45,
#     'ReportNormID': 3087,
#     'Name': '      - Nguyên giá',
#     'NameEn': '    - Cost',
#     'NameMobile': '      - Nguyên giá',
#     'NameMobileEn': '    - Cost',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding4',
#     'ParentReportNormID': 3037,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 4,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3088': {'ID': 46,
#     'ReportNormID': 3088,
#     'Name': '      - Giá trị hao mòn lũy kế (*)',
#     'NameEn': '    - Accumulated depreciation',
#     'NameMobile': '      - Giá trị hao mòn lũy kế (*)',
#     'NameMobileEn': '    - Accumulated depreciation',
#     'CssStyle': 'NormalI',
#     'Padding': 'Padding4',
#     'ParentReportNormID': 3037,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 4,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3010': {'ID': 47,
#     'ReportNormID': 3010,
#     'Name': 'III. Bất động sản đầu tư',
#     'NameEn': 'III. Investment properties',
#     'NameMobile': 'III. Bất động sản đầu tư',
#     'NameMobileEn': 'III. Investment properties',
#     'CssStyle': 'NormalB',
#     'Padding': 'Padding2',
#     'ParentReportNormID': 3001,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 2,
#     'Levels': 2,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3039': {'ID': 48,
#     'ReportNormID': 3039,
#     'Name': '      - Nguyên giá',
#     'NameEn': '    - Cost',
#     'NameMobile': '      - Nguyên giá',
#     'NameMobileEn': '    - Cost',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding4',
#     'ParentReportNormID': 3010,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3040': {'ID': 49,
#     'ReportNormID': 3040,
#     'Name': '      - Giá trị hao mòn lũy kế (*)',
#     'NameEn': '    - Accumulated depreciation',
#     'NameMobile': '      - Giá trị hao mòn lũy kế (*)',
#     'NameMobileEn': '    - Accumulated depreciation',
#     'CssStyle': 'NormalI',
#     'Padding': 'Padding4',
#     'ParentReportNormID': 3010,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '5298': {'ID': 50,
#     'ReportNormID': 5298,
#     'Name': 'IV. Tài sản dở dang dài hạn',
#     'NameEn': 'IV. Long-term assets in progress',
#     'NameMobile': 'IV. Tài sản dở dang dài hạn',
#     'NameMobileEn': 'IV. Long-term assets in progress',
#     'CssStyle': 'NormalB',
#     'Padding': 'Padding2',
#     'ParentReportNormID': 3001,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 2,
#     'Levels': 2,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '5303': {'ID': 51,
#     'ReportNormID': 5303,
#     'Name': '1. Chi phí sản xuất, kinh doanh dở dang dài hạn',
#     'NameEn': '1. Long-term production in progress',
#     'NameMobile': '1. Chi phí sản xuất, kinh doanh dở dang dài hạn',
#     'NameMobileEn': '1. Long-term production in progress',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 5298,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3038': {'ID': 52,
#     'ReportNormID': 3038,
#     'Name': '2. Chi phí xây dựng cơ bản dở dang',
#     'NameEn': '2. Construction in progress',
#     'NameMobile': '2. Chi phí xây dựng cơ bản dở dang',
#     'NameMobileEn': '2. Construction in progress',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 5298,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3011': {'ID': 53,
#     'ReportNormID': 3011,
#     'Name': 'V. Đầu tư tài chính dài hạn',
#     'NameEn': 'V. Long-term financial investments',
#     'NameMobile': 'V. Đầu tư tài chính dài hạn',
#     'NameMobileEn': 'V. Long-term financial investments',
#     'CssStyle': 'NormalB',
#     'Padding': 'Padding2',
#     'ParentReportNormID': 3001,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 6,
#     'Levels': 2,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3041': {'ID': 54,
#     'ReportNormID': 3041,
#     'Name': '1. Đầu tư vào công ty con',
#     'NameEn': '1. Investments in subsidiaries',
#     'NameMobile': '1. Đầu tư vào công ty con',
#     'NameMobileEn': '1. Investments in subsidiaries',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3011,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3042': {'ID': 55,
#     'ReportNormID': 3042,
#     'Name': '2. Đầu tư vào công ty liên kết. liên doanh',
#     'NameEn': '2. Investments in associates, joint-ventures',
#     'NameMobile': '2. Đầu tư vào công ty liên kết. liên doanh',
#     'NameMobileEn': '2. Investments in associates, joint-ventures',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3011,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '5304': {'ID': 56,
#     'ReportNormID': 5304,
#     'Name': '3. Đầu tư góp vốn vào đơn vị khác',
#     'NameEn': '3. Investments in other entities',
#     'NameMobile': '3. Đầu tư góp vốn vào đơn vị khác',
#     'NameMobileEn': '3. Investments in other entities',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3011,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3044': {'ID': 57,
#     'ReportNormID': 3044,
#     'Name': '4. Dự phòng đầu tư tài chính dài hạn (*)',
#     'NameEn': '4. Provision for diminution in value of long-term investments',
#     'NameMobile': '4. Dự phòng đầu tư tài chính dài hạn (*)',
#     'NameMobileEn': '4. Provision for diminution in value of long-term investments',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3011,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '5312': {'ID': 58,
#     'ReportNormID': 5312,
#     'Name': '5. Đầu tư nắm giữ đến ngày đáo hạn',
#     'NameEn': '5. Held to maturity investments',
#     'NameMobile': '5. Đầu tư nắm giữ đến ngày đáo hạn',
#     'NameMobileEn': '5. Held to maturity investments',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3011,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3043': {'ID': 59,
#     'ReportNormID': 3043,
#     'Name': '6. Đầu tư dài hạn khác',
#     'NameEn': '6. Other long-term investments',
#     'NameMobile': '6. Đầu tư dài hạn khác',
#     'NameMobileEn': '6. Other long-term investments',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3011,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3013': {'ID': 60,
#     'ReportNormID': 3013,
#     'Name': 'VI. Tài sản dài hạn khác',
#     'NameEn': 'VI. Other long-term assets',
#     'NameMobile': 'VI. Tài sản dài hạn khác',
#     'NameMobileEn': 'VI. Other long-term assets',
#     'CssStyle': 'NormalB',
#     'Padding': 'Padding2',
#     'ParentReportNormID': 3001,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 4,
#     'Levels': 2,
#     'Value1': 2025.0,
#     'Value2': 3944.0,
#     'Value3': 288.0,
#     'Value4': 1231.0,
#     'Vl': None,
#     'IsShowData': True},
#    '3045': {'ID': 61,
#     'ReportNormID': 3045,
#     'Name': '1. Chi phí trả trước dài hạn',
#     'NameEn': '1. Long-term prepayments',
#     'NameMobile': '1. Chi phí trả trước dài hạn',
#     'NameMobileEn': '1. Long-term prepayments',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3013,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': 2025.0,
#     'Value2': 3944.0,
#     'Value3': 288.0,
#     'Value4': 1231.0,
#     'Vl': None,
#     'IsShowData': True},
#    '3046': {'ID': 62,
#     'ReportNormID': 3046,
#     'Name': '2. Tài sản thuế thu nhập hoãn lại',
#     'NameEn': '2. Deferred income tax assets',
#     'NameMobile': '2. Tài sản thuế thu nhập hoãn lại',
#     'NameMobileEn': '2. Deferred income tax assets',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3013,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '5305': {'ID': 63,
#     'ReportNormID': 5305,
#     'Name': '3. Thiết bị, vật tư, phụ tùng thay thế dài hạn',
#     'NameEn': '3. Long-term equipment, supplies, spare parts',
#     'NameMobile': '3. Thiết bị, vật tư, phụ tùng thay thế dài hạn',
#     'NameMobileEn': '3. Long-term equipment, supplies, spare parts',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3013,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3047': {'ID': 64,
#     'ReportNormID': 3047,
#     'Name': '4. Tài sản dài hạn khác',
#     'NameEn': '4. Other long-term assets',
#     'NameMobile': '4. Tài sản dài hạn khác',
#     'NameMobileEn': '4. Other long-term assets',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding3',
#     'ParentReportNormID': 3013,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 3,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '3012': {'ID': 65,
#     'ReportNormID': 3012,
#     'Name': 'VII. Lợi thế thương mại',
#     'NameEn': 'VII. Goodwill',
#     'NameMobile': 'VII. Lợi thế thương mại',
#     'NameMobileEn': 'VII. Goodwill',
#     'CssStyle': 'NormalB',
#     'Padding': 'Padding2',
#     'ParentReportNormID': 3001,
#     'ReportComponentName': 'Cân đối kế toán',
#     'ReportComponentNameEn': 'Balance Sheet',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': None,
#     'ChildTotal': 0,
#     'Levels': 2,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '2996': {'ID': 66,
#     'ReportNormID': 2996,
#     'Name': 'TỔNG CỘNG TÀI SẢN',
#     'NameEn': 'TOTAL ASSETS',
#     'NameMobile': 'TỔNG CỘNG TÀI SẢN',
#     'NameMobileEn': 'TOTAL ASSETS',
# ...
#     'NameEn': '5. Payments for investment in other entities',
#     'NameMobile': '5. Tiền chi đầu tư góp vốn vào đơn vị khác',
#     'NameMobileEn': '5. Payments for investment in other entities',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding1',
#     'ParentReportNormID': 2271,
#     'ReportComponentName': 'Lưu chuyển tiền tệ trực tiếp',
#     'ReportComponentNameEn': 'CashFlow Direct',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': 20,
#     'ChildTotal': 0,
#     'Levels': 0,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '2283': {'ID': 66,
#     'ReportNormID': 2283,
#     'Name': '6. Tiền thu hồi đầu tư góp vốn vào đơn vị khác',
#     'NameEn': '6. Collections on investment in other entities',
#     'NameMobile': '6. Tiền thu hồi đầu tư góp vốn vào đơn vị khác',
#     'NameMobileEn': '6. Collections on investment in other entities',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding1',
#     'ParentReportNormID': 2271,
#     'ReportComponentName': 'Lưu chuyển tiền tệ trực tiếp',
#     'ReportComponentNameEn': 'CashFlow Direct',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': 20,
#     'ChildTotal': 0,
#     'Levels': 0,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '2284': {'ID': 67,
#     'ReportNormID': 2284,
#     'Name': '7. Tiền thu lãi cho vay, cổ tức và lợi nhuận được chia',
#     'NameEn': '7. Dividends, interest and profit received',
#     'NameMobile': '7. Tiền thu lãi cho vay, cổ tức và lợi nhuận được chia',
#     'NameMobileEn': '7. Dividends, interest and profit received',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding1',
#     'ParentReportNormID': 2271,
#     'ReportComponentName': 'Lưu chuyển tiền tệ trực tiếp',
#     'ReportComponentNameEn': 'CashFlow Direct',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': 20,
#     'ChildTotal': 0,
#     'Levels': 0,
#     'Value1': 0.0,
#     'Value2': None,
#     'Value3': None,
#     'Value4': 20.0,
#     'Vl': None,
#     'IsShowData': True},
#    '5280': {'ID': 68,
#     'ReportNormID': 5280,
#     'Name': '8. Tiền thu khác từ hoạt động đầu tư',
#     'NameEn': '8. Other receipts from investing activities',
#     'NameMobile': '8. Tiền thu khác từ hoạt động đầu tư',
#     'NameMobileEn': '8. Other receipts from investing activities',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding1',
#     'ParentReportNormID': 2271,
#     'ReportComponentName': 'Lưu chuyển tiền tệ trực tiếp',
#     'ReportComponentNameEn': 'CashFlow Direct',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': 20,
#     'ChildTotal': 0,
#     'Levels': 0,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '5281': {'ID': 69,
#     'ReportNormID': 5281,
#     'Name': '9. Tiền chi khác cho hoạt động đầu tư',
#     'NameEn': '9. Other payments for investing activities',
#     'NameMobile': '9. Tiền chi khác cho hoạt động đầu tư',
#     'NameMobileEn': '9. Other payments for investing activities',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding1',
#     'ParentReportNormID': 2271,
#     'ReportComponentName': 'Lưu chuyển tiền tệ trực tiếp',
#     'ReportComponentNameEn': 'CashFlow Direct',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': 20,
#     'ChildTotal': 0,
#     'Levels': 0,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '2271': {'ID': 70,
#     'ReportNormID': 2271,
#     'Name': 'Lưu chuyển tiền thuần từ hoạt động đầu tư',
#     'NameEn': 'Net cash flows from investing activities',
#     'NameMobile': 'Lưu chuyển tiền thuần từ hoạt động đầu tư',
#     'NameMobileEn': 'Net cash flows from investing activities',
#     'CssStyle': 'LargeB',
#     'Padding': 'Padding1',
#     'ParentReportNormID': 2274,
#     'ReportComponentName': 'Lưu chuyển tiền tệ trực tiếp',
#     'ReportComponentNameEn': 'CashFlow Direct',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': 20,
#     'ChildTotal': -9,
#     'Levels': 0,
#     'Value1': -1234.0,
#     'Value2': None,
#     'Value3': None,
#     'Value4': -16027.0,
#     'Vl': None,
#     'IsShowData': True},
#    '2269': {'ID': 71,
#     'ReportNormID': 2269,
#     'Name': 'III. Lưu chuyển tiền từ hoạt động tài chính',
#     'NameEn': ' III. CASH FLOWS FROM FINANCING ACTIVITIES ',
#     'NameMobile': 'III. Lưu chuyển tiền từ hoạt động tài chính',
#     'NameMobileEn': ' III. CASH FLOWS FROM FINANCING ACTIVITIES ',
#     'CssStyle': 'NormalB',
#     'Padding': 'Padding1',
#     'ParentReportNormID': 2269,
#     'ReportComponentName': 'Lưu chuyển tiền tệ trực tiếp',
#     'ReportComponentNameEn': 'CashFlow Direct',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': 20,
#     'ChildTotal': 0,
#     'Levels': 0,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '2285': {'ID': 72,
#     'ReportNormID': 2285,
#     'Name': '1. Tiền thu từ phát hành cổ phiếu, nhận vốn góp của chủ sở hữu',
#     'NameEn': "1. Receipts from equity issue and owner's capital contribution",
#     'NameMobile': '1. Tiền thu từ phát hành cổ phiếu, nhận vốn góp của chủ sở hữu',
#     'NameMobileEn': "1. Receipts from equity issue and owner's capital contribution",
#     'CssStyle': 'Normal',
#     'Padding': 'Padding1',
#     'ParentReportNormID': 2272,
#     'ReportComponentName': 'Lưu chuyển tiền tệ trực tiếp',
#     'ReportComponentNameEn': 'CashFlow Direct',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': 20,
#     'ChildTotal': 0,
#     'Levels': 0,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '2286': {'ID': 73,
#     'ReportNormID': 2286,
#     'Name': '2. Tiền chi trả vốn góp cho các chủ sở hữu, mua lại cổ phiếu của doanh nghiệp đã phát hành',
#     'NameEn': '2. Payment for share repurchases ',
#     'NameMobile': '2. Tiền chi trả vốn góp cho các chủ sở hữu, mua lại cổ phiếu của doanh nghiệp đã phát hành',
#     'NameMobileEn': '2. Payment for share repurchases ',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding1',
#     'ParentReportNormID': 2272,
#     'ReportComponentName': 'Lưu chuyển tiền tệ trực tiếp',
#     'ReportComponentNameEn': 'CashFlow Direct',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': 20,
#     'ChildTotal': 0,
#     'Levels': 0,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '2287': {'ID': 74,
#     'ReportNormID': 2287,
#     'Name': '3. Tiền thu từ đi vay',
#     'NameEn': '3. Proceeds from borrowings',
#     'NameMobile': '3. Tiền thu từ đi vay',
#     'NameMobileEn': '3. Proceeds from borrowings',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding1',
#     'ParentReportNormID': 2272,
#     'ReportComponentName': 'Lưu chuyển tiền tệ trực tiếp',
#     'ReportComponentNameEn': 'CashFlow Direct',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': 20,
#     'ChildTotal': 0,
#     'Levels': 0,
#     'Value1': 2480.0,
#     'Value2': None,
#     'Value3': None,
#     'Value4': 22180.0,
#     'Vl': None,
#     'IsShowData': True},
#    '2288': {'ID': 75,
#     'ReportNormID': 2288,
#     'Name': '4. Tiền chi trả nợ gốc vay',
#     'NameEn': '4. Principal repayments  ',
#     'NameMobile': '4. Tiền chi trả nợ gốc vay',
#     'NameMobileEn': '4. Principal repayments  ',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding1',
#     'ParentReportNormID': 2272,
#     'ReportComponentName': 'Lưu chuyển tiền tệ trực tiếp',
#     'ReportComponentNameEn': 'CashFlow Direct',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': 20,
#     'ChildTotal': 0,
#     'Levels': 0,
#     'Value1': -1593.0,
#     'Value2': None,
#     'Value3': None,
#     'Value4': -6381.0,
#     'Vl': None,
#     'IsShowData': True},
#    '2289': {'ID': 76,
#     'ReportNormID': 2289,
#     'Name': '5. Tiền trả nợ gốc thuê tài chính',
#     'NameEn': '5. Repayment of financial leases',
#     'NameMobile': '5. Tiền trả nợ gốc thuê tài chính',
#     'NameMobileEn': '5. Repayment of financial leases',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding1',
#     'ParentReportNormID': 2272,
#     'ReportComponentName': 'Lưu chuyển tiền tệ trực tiếp',
#     'ReportComponentNameEn': 'CashFlow Direct',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': 20,
#     'ChildTotal': 0,
#     'Levels': 0,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '2290': {'ID': 77,
#     'ReportNormID': 2290,
#     'Name': '6. Cổ tức, lợi nhuận đã trả cho chủ sở hữu',
#     'NameEn': '6. Dividends paid, profits distributed to owners',
#     'NameMobile': '6. Cổ tức, lợi nhuận đã trả cho chủ sở hữu',
#     'NameMobileEn': '6. Dividends paid, profits distributed to owners',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding1',
#     'ParentReportNormID': 2272,
#     'ReportComponentName': 'Lưu chuyển tiền tệ trực tiếp',
#     'ReportComponentNameEn': 'CashFlow Direct',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': 20,
#     'ChildTotal': 0,
#     'Levels': 0,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '5282': {'ID': 78,
#     'ReportNormID': 5282,
#     'Name': '7. Tiền thu khác từ hoạt động tài chính',
#     'NameEn': '7. Other receipts from financing activities',
#     'NameMobile': '7. Tiền thu khác từ hoạt động tài chính',
#     'NameMobileEn': '7. Other receipts from financing activities',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding1',
#     'ParentReportNormID': 2272,
#     'ReportComponentName': 'Lưu chuyển tiền tệ trực tiếp',
#     'ReportComponentNameEn': 'CashFlow Direct',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': 20,
#     'ChildTotal': 0,
#     'Levels': 0,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '5283': {'ID': 79,
#     'ReportNormID': 5283,
#     'Name': '8. Tiền chi khác cho hoạt động tài chính',
#     'NameEn': '8. Other payments for financing activities',
#     'NameMobile': '8. Tiền chi khác cho hoạt động tài chính',
#     'NameMobileEn': '8. Other payments for financing activities',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding1',
#     'ParentReportNormID': 2272,
#     'ReportComponentName': 'Lưu chuyển tiền tệ trực tiếp',
#     'ReportComponentNameEn': 'CashFlow Direct',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': 20,
#     'ChildTotal': 0,
#     'Levels': 0,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '2272': {'ID': 80,
#     'ReportNormID': 2272,
#     'Name': 'Lưu chuyển tiền thuần từ hoạt động tài chính',
#     'NameEn': 'Net cash flows from financing activities',
#     'NameMobile': 'Lưu chuyển tiền thuần từ hoạt động tài chính',
#     'NameMobileEn': 'Net cash flows from financing activities',
#     'CssStyle': 'LargeB',
#     'Padding': 'Padding1',
#     'ParentReportNormID': 2274,
#     'ReportComponentName': 'Lưu chuyển tiền tệ trực tiếp',
#     'ReportComponentNameEn': 'CashFlow Direct',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': 20,
#     'ChildTotal': -8,
#     'Levels': 0,
#     'Value1': 887.0,
#     'Value2': None,
#     'Value3': None,
#     'Value4': 15799.0,
#     'Vl': None,
#     'IsShowData': True},
#    '2274': {'ID': 81,
#     'ReportNormID': 2274,
#     'Name': 'Lưu chuyển tiền thuần trong kỳ',
#     'NameEn': 'Net cash flows during the period ',
#     'NameMobile': 'Lưu chuyển tiền thuần trong kỳ',
#     'NameMobileEn': 'Net cash flows during the period ',
#     'CssStyle': 'NormalB',
#     'Padding': 'Padding1',
#     'ParentReportNormID': 2276,
#     'ReportComponentName': 'Lưu chuyển tiền tệ trực tiếp',
#     'ReportComponentNameEn': 'CashFlow Direct',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': 20,
#     'ChildTotal': 0,
#     'Levels': 0,
#     'Value1': -860.0,
#     'Value2': None,
#     'Value3': None,
#     'Value4': -3731.0,
#     'Vl': None,
#     'IsShowData': True},
#    '2275': {'ID': 82,
#     'ReportNormID': 2275,
#     'Name': 'Tiền và tương đương tiền đầu kỳ',
#     'NameEn': 'Cash and cash equivalents at beginning of the period',
#     'NameMobile': 'Tiền và tương đương tiền đầu kỳ',
#     'NameMobileEn': 'Cash and cash equivalents at beginning of the period',
#     'CssStyle': 'NormalB',
#     'Padding': 'Padding1',
#     'ParentReportNormID': 2276,
#     'ReportComponentName': 'Lưu chuyển tiền tệ trực tiếp',
#     'ReportComponentNameEn': 'CashFlow Direct',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': 20,
#     'ChildTotal': 0,
#     'Levels': 0,
#     'Value1': 917.0,
#     'Value2': None,
#     'Value3': None,
#     'Value4': 4190.0,
#     'Vl': None,
#     'IsShowData': True},
#    '2273': {'ID': 83,
#     'ReportNormID': 2273,
#     'Name': 'Ảnh hưởng của thay đổi tỷ giá hối đoái quy đổi ngoại tệ',
#     'NameEn': 'Exchange difference due to re-valuation of ending balances',
#     'NameMobile': 'Ảnh hưởng của thay đổi tỷ giá hối đoái quy đổi ngoại tệ',
#     'NameMobileEn': 'Exchange difference due to re-valuation of ending balances',
#     'CssStyle': 'Normal',
#     'Padding': 'Padding1',
#     'ParentReportNormID': 2276,
#     'ReportComponentName': 'Lưu chuyển tiền tệ trực tiếp',
#     'ReportComponentNameEn': 'CashFlow Direct',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': 20,
#     'ChildTotal': 0,
#     'Levels': 0,
#     'Value1': None,
#     'Value2': None,
#     'Value3': None,
#     'Value4': None,
#     'Vl': None,
#     'IsShowData': True},
#    '2276': {'ID': 84,
#     'ReportNormID': 2276,
#     'Name': 'Tiền và tương đương tiền cuối kỳ',
#     'NameEn': 'Cash and cash equivalents at end of the period',
#     'NameMobile': 'Tiền và tương đương tiền cuối kỳ',
#     'NameMobileEn': 'Cash and cash equivalents at end of the period',
#     'CssStyle': 'NormalB',
#     'Padding': 'Padding1',
#     'ParentReportNormID': 2276,
#     'ReportComponentName': 'Lưu chuyển tiền tệ trực tiếp',
#     'ReportComponentNameEn': 'CashFlow Direct',
#     'Unit': None,
#     'UnitEn': None,
#     'OrderType': None,
#     'OrderingComponent': None,
#     'RowNumber': None,
#     'ReportComponentTypeID': 20,
#     'ChildTotal': 0,
#     'Levels': 0,
#     'Value1': 57.0,
#     'Value2': None,
#     'Value3': None,
#     'Value4': 459.0,
#     'Vl': None,
#     'IsShowData': True}}}}

# %%
### Generate entry and return FAD account
def get_FAD_acc(report, report_fullname, d, lookup_dict, mapping_dict):
    """Input is a dict which is an account of a report in the financeInfo API;
    Returns the final FAD account name
    """
    acc_n = simplifyText(d['NameEn'])
    acc_vi_n = simplifyText(d['Name'])
    parent_n = simplifyText(lookup_dict[report][report_fullname][str(d['ParentReportNormID'])]['NameEn'])
    parent_vi_n = simplifyText(lookup_dict[report][report_fullname][str(d['ParentReportNormID'])]['Name'])
    try:
        return mapping_dict[report][report_fullname][f'{acc_n};{parent_n};{acc_vi_n};{parent_vi_n}']
    except:
        return "N/A"

# %%
### Testing
for file in glob.glob(f'functions/schemaData/financeInfo/*_*_*_CDKT_Annual_*.json')[:20]:
    file_components = file.split("_")
    if file_components[1] != "Finance and Insurance":
        report = file_components[3]
        with open(file, 'r') as jsonfile:
            try:
                j = json.load(jsonfile)
                report_fullname = list(j[1].keys())[0]
                for account_content in j[1][report_fullname]:
                    print(get_FAD_acc(report, report_fullname, account_content, lookup, mapping_dict_all))
            except Exception as e:
                print(traceback.format_exc())
# Out:
# N/A
# current_assets
# cash_cash_equiv
# cash
# cash_equiv
# st_invmts
# hld_trading_secs_st
# pvsn_hld_trading_secs
# hld_mature_invmts
# current_ar
# st_trade_ar
# st_adv_suppliers
# st_internal_ar
# construction_cntrct_ar
# st_loan_ar
# other_st_ar
# pvsn_doubt_st_ar
# st_wait_resolution
# inventories_all
# inventories
# pvsn_obsolete_inventories
# other_current_assets_all
# st_prepaid_exp
# vat_deductible
# from_state_tax_ar
# gov_bonds_hld_resale
# other_current_assets
# noncurrent_assets
# lt_ar
# lt_trade_ar
# lt_adv_suppliers
# pd_capital_dependent
# lt_internal_ar
# lt_loan_ar
# other_lt_ar
# pvsn_doubt_lt_ar
# fixed_assets
# tgbl_fixed_assets
# tgbl_fixed_assets_cost
# tgbl_fixed_assets_depre
# fin_leases
# fin_leases_cost
# fin_leases_cost_depre
# intgbl_fixed_assets
# intgbl_fixed_assets_cost
# intgbl_fixed_assets_amor
# invmts_properties
# invmts_properties_cost
# invmts_properties_depre
# lt_assets_in_progress
# lt_wip
# construction_wip
# lt_invmts
# invmts_subs
# invmts_assocs
# invmts_other_entities
# pvsn_lt_invmts
# hld_mature_invmts_lt
# other_lt_invmts
# other_lt_assets_all
# lt_prepaid_exp
# deferred_tax_assets
# lt_tools_materials
# other_lt_assets
# goodwill
# total_assets
# N/A
# liabilities
# current_liabilities
# st_trade_ap
# st_adv_customers
# stat_obligations
# ap_employees
# st_accrued_exp
# st_internal_ap
# construction_cntrct_ap
# st_unearned_rev
# st_other_ap
# st_loan_finlease_ap
# st_pvsn
# bonus_wf_fund
# price_stabili_fund
# gov_bonds_hld_purchase
# noncurrent_liabilities
# lt_trade_ap
# lt_adv_customers
# lt_accrued_exp
# lt_internal_ap_capital
# lt_internal_ap
# lt_unearned_rev
# other_lt_liabilities
# st_loan_finlease_ap
# convert_bonds_liabilities
# pref_shares_liabilities
# deferred_tax_liabilities
# lt_pvsn
# sci_tech_dev_fund
# pvsn_sever_allowances
# owners_equity
# capital
# contrib_charter_capital
# shares_vote_rights
# pref_shares_equity
# share_premium
# convertible_bonds_equity
# other_owner_capital
# treasury_shares
# asset_reval_reserve
# forex_diff_reserve
# invmt_dev_fund
# enterprise_reorg_supp_fund
# other_funds_equity
# undis_earnings_losses
# undis_earnings_losses_prior
# undis_earnings_losses_current
# fund_capex
# non_ctrl_interests
# fin_reserves
# other_funds_all
# subsidized_fund
# fund_fixed_assets_in_use
# minority_interest
# total_liabilities_equity
# N/A
# current_assets
# cash_cash_equiv
# cash
# cash_equiv
# st_invmts
# hld_trading_secs_st
# pvsn_hld_trading_secs
# hld_mature_invmts
# current_ar
# st_trade_ar
# st_adv_suppliers
# st_internal_ar
# construction_cntrct_ar
# st_loan_ar
# other_st_ar
# pvsn_doubt_st_ar
# st_wait_resolution
# inventories_all
# inventories
# pvsn_obsolete_inventories
# other_current_assets_all
# st_prepaid_exp
# vat_deductible
# from_state_tax_ar
# gov_bonds_hld_resale
# other_current_assets
# noncurrent_assets
# lt_ar
# lt_trade_ar
# lt_adv_suppliers
# pd_capital_dependent
# lt_internal_ar
# lt_loan_ar
# other_lt_ar
# pvsn_doubt_lt_ar
# fixed_assets
# tgbl_fixed_assets
# tgbl_fixed_assets_cost
# tgbl_fixed_assets_depre
# fin_leases
# fin_leases_cost
# fin_leases_cost_depre
# intgbl_fixed_assets
# intgbl_fixed_assets_cost
# intgbl_fixed_assets_amor
# invmts_properties
# invmts_properties_cost
# invmts_properties_depre
# lt_assets_in_progress
# lt_wip
# construction_wip
# lt_invmts
# invmts_subs
# invmts_assocs
# invmts_other_entities
# pvsn_lt_invmts
# hld_mature_invmts_lt
# other_lt_invmts
# other_lt_assets_all
# lt_prepaid_exp
# deferred_tax_assets
# lt_tools_materials
# other_lt_assets
# goodwill
# total_assets
# N/A
# liabilities
# current_liabilities
# st_trade_ap
# st_adv_customers
# stat_obligations
# ap_employees
# st_accrued_exp
# st_internal_ap
# construction_cntrct_ap
# st_unearned_rev
# st_other_ap
# st_loan_finlease_ap
# st_pvsn
# bonus_wf_fund
# price_stabili_fund
# gov_bonds_hld_purchase
# noncurrent_liabilities
# lt_trade_ap
# lt_adv_customers
# lt_accrued_exp
# lt_internal_ap_capital
# lt_internal_ap
# lt_unearned_rev
# other_lt_liabilities
# st_loan_finlease_ap
# convert_bonds_liabilities
# pref_shares_liabilities
# deferred_tax_liabilities
# lt_pvsn
# sci_tech_dev_fund
# pvsn_sever_allowances
# owners_equity
# capital
# contrib_charter_capital
# shares_vote_rights
# pref_shares_equity
# share_premium
# convertible_bonds_equity
# other_owner_capital
# treasury_shares
# asset_reval_reserve
# forex_diff_reserve
# invmt_dev_fund
# enterprise_reorg_supp_fund
# other_funds_equity
# undis_earnings_losses
# undis_earnings_losses_prior
# undis_earnings_losses_current
# fund_capex
# non_ctrl_interests
# fin_reserves
# other_funds_all
# subsidized_fund
# fund_fixed_assets_in_use
# minority_interest
# total_liabilities_equity
# N/A
# current_assets
# cash_cash_equiv
# cash
# cash_equiv
# st_invmts
# hld_trading_secs_st
# pvsn_hld_trading_secs
# hld_mature_invmts
# current_ar
# st_trade_ar
# st_adv_suppliers
# st_internal_ar
# construction_cntrct_ar
# st_loan_ar
# other_st_ar
# pvsn_doubt_st_ar
# st_wait_resolution
# inventories_all
# inventories
# pvsn_obsolete_inventories
# other_current_assets_all
# st_prepaid_exp
# vat_deductible
# from_state_tax_ar
# gov_bonds_hld_resale
# other_current_assets
# noncurrent_assets
# lt_ar
# lt_trade_ar
# lt_adv_suppliers
# pd_capital_dependent
# lt_internal_ar
# lt_loan_ar
# other_lt_ar
# pvsn_doubt_lt_ar
# fixed_assets
# tgbl_fixed_assets
# tgbl_fixed_assets_cost
# tgbl_fixed_assets_depre
# fin_leases
# fin_leases_cost
# fin_leases_cost_depre
# intgbl_fixed_assets
# intgbl_fixed_assets_cost
# intgbl_fixed_assets_amor
# invmts_properties
# invmts_properties_cost
# invmts_properties_depre
# lt_assets_in_progress
# lt_wip
# construction_wip
# lt_invmts
# invmts_subs
# invmts_assocs
# invmts_other_entities
# pvsn_lt_invmts
# hld_mature_invmts_lt
# other_lt_invmts
# other_lt_assets_all
# lt_prepaid_exp
# deferred_tax_assets
# lt_tools_materials
# other_lt_assets
# goodwill
# total_assets
# N/A
# liabilities
# current_liabilities
# st_trade_ap
# st_adv_customers
# stat_obligations
# ap_employees
# st_accrued_exp
# st_internal_ap
# construction_cntrct_ap
# st_unearned_rev
# st_other_ap
# st_loan_finlease_ap
# st_pvsn
# bonus_wf_fund
# price_stabili_fund
# gov_bonds_hld_purchase
# noncurrent_liabilities
# lt_trade_ap
# lt_adv_customers
# lt_accrued_exp
# lt_internal_ap_capital
# lt_internal_ap
# lt_unearned_rev
# other_lt_liabilities
# st_loan_finlease_ap
# convert_bonds_liabilities
# pref_shares_liabilities
# deferred_tax_liabilities
# lt_pvsn
# sci_tech_dev_fund
# pvsn_sever_allowances
# owners_equity
# capital
# contrib_charter_capital
# shares_vote_rights
# pref_shares_equity
# share_premium
# convertible_bonds_equity
# other_owner_capital
# treasury_shares
# asset_reval_reserve
# forex_diff_reserve
# invmt_dev_fund
# enterprise_reorg_supp_fund
# other_funds_equity
# undis_earnings_losses
# undis_earnings_losses_prior
# undis_earnings_losses_current
# fund_capex
# non_ctrl_interests
# fin_reserves
# other_funds_all
# subsidized_fund
# fund_fixed_assets_in_use
# minority_interest
# total_liabilities_equity
# N/A
# current_assets
# cash_cash_equiv
# cash
# cash_equiv
# st_invmts
# hld_trading_secs_st
# pvsn_hld_trading_secs
# hld_mature_invmts
# current_ar
# st_trade_ar
# st_adv_suppliers
# st_internal_ar
# construction_cntrct_ar
# st_loan_ar
# other_st_ar
# pvsn_doubt_st_ar
# st_wait_resolution
# inventories_all
# inventories
# pvsn_obsolete_inventories
# other_current_assets_all
# st_prepaid_exp
# vat_deductible
# from_state_tax_ar
# gov_bonds_hld_resale
# other_current_assets
# noncurrent_assets
# lt_ar
# lt_trade_ar
# lt_adv_suppliers
# pd_capital_dependent
# lt_internal_ar
# lt_loan_ar
# other_lt_ar
# pvsn_doubt_lt_ar
# fixed_assets
# tgbl_fixed_assets
# tgbl_fixed_assets_cost
# tgbl_fixed_assets_depre
# fin_leases
# fin_leases_cost
# fin_leases_cost_depre
# intgbl_fixed_assets
# intgbl_fixed_assets_cost
# intgbl_fixed_assets_amor
# invmts_properties
# invmts_properties_cost
# invmts_properties_depre
# lt_assets_in_progress
# lt_wip
# construction_wip
# lt_invmts
# invmts_subs
# invmts_assocs
# invmts_other_entities
# pvsn_lt_invmts
# hld_mature_invmts_lt
# other_lt_invmts
# other_lt_assets_all
# lt_prepaid_exp
# deferred_tax_assets
# lt_tools_materials
# other_lt_assets
# goodwill
# total_assets
# N/A
# liabilities
# current_liabilities
# st_trade_ap
# st_adv_customers
# stat_obligations
# ap_employees
# st_accrued_exp
# st_internal_ap
# construction_cntrct_ap
# st_unearned_rev
# st_other_ap
# st_loan_finlease_ap
# st_pvsn
# bonus_wf_fund
# price_stabili_fund
# gov_bonds_hld_purchase
# noncurrent_liabilities
# lt_trade_ap
# lt_adv_customers
# lt_accrued_exp
# lt_internal_ap_capital
# lt_internal_ap
# lt_unearned_rev
# other_lt_liabilities
# st_loan_finlease_ap
# convert_bonds_liabilities
# pref_shares_liabilities
# deferred_tax_liabilities
# lt_pvsn
# sci_tech_dev_fund
# pvsn_sever_allowances
# owners_equity
# capital
# contrib_charter_capital
# shares_vote_rights
# pref_shares_equity
# share_premium
# convertible_bonds_equity
# other_owner_capital
# treasury_shares
# asset_reval_reserve
# forex_diff_reserve
# invmt_dev_fund
# enterprise_reorg_supp_fund
# other_funds_equity
# undis_earnings_losses
# undis_earnings_losses_prior
# undis_earnings_losses_current
# fund_capex
# non_ctrl_interests
# fin_reserves
# other_funds_all
# subsidized_fund
# fund_fixed_assets_in_use
# minority_interest
# total_liabilities_equity
# N/A
# current_assets
# cash_cash_equiv
# cash
# cash_equiv
# st_invmts
# hld_trading_secs_st
# pvsn_hld_trading_secs
# hld_mature_invmts
# current_ar
# st_trade_ar
# st_adv_suppliers
# st_internal_ar
# construction_cntrct_ar
# st_loan_ar
# other_st_ar
# pvsn_doubt_st_ar
# st_wait_resolution
# inventories_all
# inventories
# pvsn_obsolete_inventories
# other_current_assets_all
# st_prepaid_exp
# vat_deductible
# from_state_tax_ar
# gov_bonds_hld_resale
# other_current_assets
# noncurrent_assets
# lt_ar
# lt_trade_ar
# lt_adv_suppliers
# pd_capital_dependent
# lt_internal_ar
# lt_loan_ar
# other_lt_ar
# pvsn_doubt_lt_ar
# fixed_assets
# tgbl_fixed_assets
# tgbl_fixed_assets_cost
# tgbl_fixed_assets_depre
# fin_leases
# fin_leases_cost
# fin_leases_cost_depre
# intgbl_fixed_assets
# intgbl_fixed_assets_cost
# intgbl_fixed_assets_amor
# invmts_properties
# invmts_properties_cost
# invmts_properties_depre
# lt_assets_in_progress
# lt_wip
# construction_wip
# lt_invmts
# invmts_subs
# invmts_assocs
# invmts_other_entities
# pvsn_lt_invmts
# hld_mature_invmts_lt
# other_lt_invmts
# other_lt_assets_all
# lt_prepaid_exp
# deferred_tax_assets
# lt_tools_materials
# other_lt_assets
# goodwill
# total_assets
# N/A
# liabilities
# current_liabilities
# st_trade_ap
# st_adv_customers
# stat_obligations
# ap_employees
# st_accrued_exp
# st_internal_ap
# construction_cntrct_ap
# st_unearned_rev
# st_other_ap
# st_loan_finlease_ap
# st_pvsn
# bonus_wf_fund
# price_stabili_fund
# gov_bonds_hld_purchase
# noncurrent_liabilities
# lt_trade_ap
# lt_adv_customers
# lt_accrued_exp
# lt_internal_ap_capital
# lt_internal_ap
# lt_unearned_rev
# other_lt_liabilities
# st_loan_finlease_ap
# convert_bonds_liabilities
# pref_shares_liabilities
# deferred_tax_liabilities
# lt_pvsn
# sci_tech_dev_fund
# pvsn_sever_allowances
# owners_equity
# capital
# contrib_charter_capital
# shares_vote_rights
# pref_shares_equity
# share_premium
# convertible_bonds_equity
# other_owner_capital
# treasury_shares
# asset_reval_reserve
# forex_diff_reserve
# invmt_dev_fund
# enterprise_reorg_supp_fund
# other_funds_equity
# undis_earnings_losses
# undis_earnings_losses_prior
# undis_earnings_losses_current
# fund_capex
# non_ctrl_interests
# fin_reserves
# other_funds_all
# subsidized_fund
# fund_fixed_assets_in_use
# minority_interest
# total_liabilities_equity
# N/A
# current_assets
# cash_cash_equiv
# cash
# cash_equiv
# st_invmts
# hld_trading_secs_st
# pvsn_hld_trading_secs
# hld_mature_invmts
# current_ar
# st_trade_ar
# st_adv_suppliers
# st_internal_ar
# construction_cntrct_ar
# st_loan_ar
# other_st_ar
# pvsn_doubt_st_ar
# st_wait_resolution
# inventories_all
# inventories
# pvsn_obsolete_inventories
# other_current_assets_all
# st_prepaid_exp
# vat_deductible
# from_state_tax_ar
# gov_bonds_hld_resale
# other_current_assets
# noncurrent_assets
# lt_ar
# lt_trade_ar
# lt_adv_suppliers
# pd_capital_dependent
# lt_internal_ar
# lt_loan_ar
# other_lt_ar
# pvsn_doubt_lt_ar
# fixed_assets
# tgbl_fixed_assets
# tgbl_fixed_assets_cost
# tgbl_fixed_assets_depre
# fin_leases
# fin_leases_cost
# fin_leases_cost_depre
# intgbl_fixed_assets
# intgbl_fixed_assets_cost
# intgbl_fixed_assets_amor
# invmts_properties
# invmts_properties_cost
# invmts_properties_depre
# lt_assets_in_progress
# lt_wip
# construction_wip
# lt_invmts
# invmts_subs
# invmts_assocs
# invmts_other_entities
# pvsn_lt_invmts
# hld_mature_invmts_lt
# other_lt_invmts
# other_lt_assets_all
# lt_prepaid_exp
# deferred_tax_assets
# lt_tools_materials
# other_lt_assets
# goodwill
# total_assets
# N/A
# liabilities
# current_liabilities
# st_trade_ap
# st_adv_customers
# stat_obligations
# ap_employees
# st_accrued_exp
# st_internal_ap
# construction_cntrct_ap
# st_unearned_rev
# st_other_ap
# st_loan_finlease_ap
# st_pvsn
# bonus_wf_fund
# price_stabili_fund
# gov_bonds_hld_purchase
# noncurrent_liabilities
# lt_trade_ap
# lt_adv_customers
# lt_accrued_exp
# lt_internal_ap_capital
# lt_internal_ap
# lt_unearned_rev
# other_lt_liabilities
# st_loan_finlease_ap
# convert_bonds_liabilities
# pref_shares_liabilities
# deferred_tax_liabilities
# lt_pvsn
# sci_tech_dev_fund
# pvsn_sever_allowances
# owners_equity
# capital
# contrib_charter_capital
# shares_vote_rights
# pref_shares_equity
# share_premium
# convertible_bonds_equity
# other_owner_capital
# treasury_shares
# asset_reval_reserve
# forex_diff_reserve
# invmt_dev_fund
# enterprise_reorg_supp_fund
# other_funds_equity
# undis_earnings_losses
# undis_earnings_losses_prior
# undis_earnings_losses_current
# fund_capex
# non_ctrl_interests
# fin_reserves
# other_funds_all
# subsidized_fund
# fund_fixed_assets_in_use
# minority_interest
# total_liabilities_equity
# N/A
# current_assets
# cash_cash_equiv
# cash
# cash_equiv
# st_invmts
# hld_trading_secs_st
# pvsn_hld_trading_secs
# hld_mature_invmts
# current_ar
# st_trade_ar
# st_adv_suppliers
# st_internal_ar
# construction_cntrct_ar
# st_loan_ar
# other_st_ar
# pvsn_doubt_st_ar
# st_wait_resolution
# inventories_all
# inventories
# pvsn_obsolete_inventories
# other_current_assets_all
# st_prepaid_exp
# vat_deductible
# from_state_tax_ar
# gov_bonds_hld_resale
# other_current_assets
# noncurrent_assets
# lt_ar
# lt_trade_ar
# lt_adv_suppliers
# pd_capital_dependent
# lt_internal_ar
# lt_loan_ar
# other_lt_ar
# pvsn_doubt_lt_ar
# fixed_assets
# tgbl_fixed_assets
# tgbl_fixed_assets_cost
# tgbl_fixed_assets_depre
# fin_leases
# fin_leases_cost
# fin_leases_cost_depre
# intgbl_fixed_assets
# intgbl_fixed_assets_cost
# intgbl_fixed_assets_amor
# invmts_properties
# invmts_properties_cost
# invmts_properties_depre
# lt_assets_in_progress
# lt_wip
# construction_wip
# lt_invmts
# invmts_subs
# invmts_assocs
# invmts_other_entities
# pvsn_lt_invmts
# hld_mature_invmts_lt
# other_lt_invmts
# other_lt_assets_all
# lt_prepaid_exp
# deferred_tax_assets
# lt_tools_materials
# other_lt_assets
# goodwill
# total_assets
# N/A
# liabilities
# current_liabilities
# st_trade_ap
# st_adv_customers
# stat_obligations
# ap_employees
# st_accrued_exp
# st_internal_ap
# construction_cntrct_ap
# st_unearned_rev
# st_other_ap
# st_loan_finlease_ap
# st_pvsn
# bonus_wf_fund
# price_stabili_fund
# gov_bonds_hld_purchase
# noncurrent_liabilities
# lt_trade_ap
# lt_adv_customers
# lt_accrued_exp
# lt_internal_ap_capital
# lt_internal_ap
# lt_unearned_rev
# other_lt_liabilities
# st_loan_finlease_ap
# convert_bonds_liabilities
# pref_shares_liabilities
# deferred_tax_liabilities
# lt_pvsn
# sci_tech_dev_fund
# pvsn_sever_allowances
# owners_equity
# capital
# contrib_charter_capital
# shares_vote_rights
# pref_shares_equity
# share_premium
# convertible_bonds_equity
# other_owner_capital
# treasury_shares
# asset_reval_reserve
# forex_diff_reserve
# invmt_dev_fund
# enterprise_reorg_supp_fund
# other_funds_equity
# undis_earnings_losses
# undis_earnings_losses_prior
# undis_earnings_losses_current
# fund_capex
# non_ctrl_interests
# fin_reserves
# other_funds_all
# subsidized_fund
# fund_fixed_assets_in_use
# minority_interest
# total_liabilities_equity
# N/A
# current_assets
# cash_cash_equiv
# cash
# cash_equiv
# st_invmts
# hld_trading_secs_st
# pvsn_hld_trading_secs
# hld_mature_invmts
# current_ar
# st_trade_ar
# st_adv_suppliers
# st_internal_ar
# construction_cntrct_ar
# st_loan_ar
# other_st_ar
# pvsn_doubt_st_ar
# st_wait_resolution
# inventories_all
# inventories
# pvsn_obsolete_inventories
# other_current_assets_all
# st_prepaid_exp
# vat_deductible
# from_state_tax_ar
# gov_bonds_hld_resale
# other_current_assets
# noncurrent_assets
# lt_ar
# lt_trade_ar
# lt_adv_suppliers
# pd_capital_dependent
# lt_internal_ar
# lt_loan_ar
# other_lt_ar
# pvsn_doubt_lt_ar
# fixed_assets
# tgbl_fixed_assets
# tgbl_fixed_assets_cost
# tgbl_fixed_assets_depre
# fin_leases
# fin_leases_cost
# fin_leases_cost_depre
# intgbl_fixed_assets
# intgbl_fixed_assets_cost
# intgbl_fixed_assets_amor
# invmts_properties
# invmts_properties_cost
# invmts_properties_depre
# lt_assets_in_progress
# lt_wip
# construction_wip
# lt_invmts
# invmts_subs
# invmts_assocs
# invmts_other_entities
# pvsn_lt_invmts
# hld_mature_invmts_lt
# other_lt_invmts
# other_lt_assets_all
# lt_prepaid_exp
# deferred_tax_assets
# lt_tools_materials
# other_lt_assets
# goodwill
# total_assets
# N/A
# liabilities
# current_liabilities
# st_trade_ap
# st_adv_customers
# stat_obligations
# ap_employees
# st_accrued_exp
# st_internal_ap
# construction_cntrct_ap
# st_unearned_rev
# st_other_ap
# st_loan_finlease_ap
# st_pvsn
# bonus_wf_fund
# price_stabili_fund
# gov_bonds_hld_purchase
# noncurrent_liabilities
# lt_trade_ap
# lt_adv_customers
# lt_accrued_exp
# lt_internal_ap_capital
# lt_internal_ap
# lt_unearned_rev
# other_lt_liabilities
# st_loan_finlease_ap
# convert_bonds_liabilities
# pref_shares_liabilities
# deferred_tax_liabilities
# lt_pvsn
# sci_tech_dev_fund
# pvsn_sever_allowances
# owners_equity
# capital
# contrib_charter_capital
# shares_vote_rights
# pref_shares_equity
# share_premium
# convertible_bonds_equity
# other_owner_capital
# treasury_shares
# asset_reval_reserve
# forex_diff_reserve
# invmt_dev_fund
# enterprise_reorg_supp_fund
# other_funds_equity
# undis_earnings_losses
# undis_earnings_losses_prior
# undis_earnings_losses_current
# fund_capex
# non_ctrl_interests
# fin_reserves
# other_funds_all
# subsidized_fund
# fund_fixed_assets_in_use
# minority_interest
# total_liabilities_equity
# N/A
# current_assets
# cash_cash_equiv
# cash
# cash_equiv
# st_invmts
# hld_trading_secs_st
# pvsn_hld_trading_secs
# hld_mature_invmts
# current_ar
# st_trade_ar
# st_adv_suppliers
# st_internal_ar
# construction_cntrct_ar
# st_loan_ar
# other_st_ar
# pvsn_doubt_st_ar
# st_wait_resolution
# inventories_all
# inventories
# pvsn_obsolete_inventories
# other_current_assets_all
# st_prepaid_exp
# vat_deductible
# from_state_tax_ar
# gov_bonds_hld_resale
# other_current_assets
# noncurrent_assets
# lt_ar
# lt_trade_ar
# lt_adv_suppliers
# pd_capital_dependent
# lt_internal_ar
# lt_loan_ar
# other_lt_ar
# pvsn_doubt_lt_ar
# fixed_assets
# tgbl_fixed_assets
# tgbl_fixed_assets_cost
# tgbl_fixed_assets_depre
# fin_leases
# fin_leases_cost
# fin_leases_cost_depre
# intgbl_fixed_assets
# intgbl_fixed_assets_cost
# intgbl_fixed_assets_amor
# invmts_properties
# invmts_properties_cost
# invmts_properties_depre
# lt_assets_in_progress
# lt_wip
# construction_wip
# lt_invmts
# invmts_subs
# invmts_assocs
# invmts_other_entities
# pvsn_lt_invmts
# hld_mature_invmts_lt
# other_lt_invmts
# other_lt_assets_all
# lt_prepaid_exp
# deferred_tax_assets
# lt_tools_materials
# other_lt_assets
# goodwill
# total_assets
# N/A
# liabilities
# current_liabilities
# st_trade_ap
# st_adv_customers
# stat_obligations
# ap_employees
# st_accrued_exp
# st_internal_ap
# construction_cntrct_ap
# st_unearned_rev
# st_other_ap
# st_loan_finlease_ap
# st_pvsn
# bonus_wf_fund
# price_stabili_fund
# gov_bonds_hld_purchase
# noncurrent_liabilities
# lt_trade_ap
# lt_adv_customers
# lt_accrued_exp
# lt_internal_ap_capital
# lt_internal_ap
# lt_unearned_rev
# other_lt_liabilities
# st_loan_finlease_ap
# convert_bonds_liabilities
# pref_shares_liabilities
# deferred_tax_liabilities
# lt_pvsn
# sci_tech_dev_fund
# pvsn_sever_allowances
# owners_equity
# capital
# contrib_charter_capital
# shares_vote_rights
# pref_shares_equity
# share_premium
# convertible_bonds_equity
# other_owner_capital
# treasury_shares
# asset_reval_reserve
# forex_diff_reserve
# invmt_dev_fund
# enterprise_reorg_supp_fund
# other_funds_equity
# undis_earnings_losses
# undis_earnings_losses_prior
# undis_earnings_losses_current
# fund_capex
# non_ctrl_interests
# fin_reserves
# other_funds_all
# subsidized_fund
# fund_fixed_assets_in_use
# minority_interest
# total_liabilities_equity
# N/A
# current_assets
# cash_cash_equiv
# cash
# cash_equiv
# st_invmts
# hld_trading_secs_st
# pvsn_hld_trading_secs
# hld_mature_invmts
# current_ar
# st_trade_ar
# st_adv_suppliers
# st_internal_ar
# construction_cntrct_ar
# st_loan_ar
# other_st_ar
# pvsn_doubt_st_ar
# st_wait_resolution
# inventories_all
# inventories
# pvsn_obsolete_inventories
# other_current_assets_all
# st_prepaid_exp
# vat_deductible
# from_state_tax_ar
# gov_bonds_hld_resale
# other_current_assets
# noncurrent_assets
# lt_ar
# lt_trade_ar
# lt_adv_suppliers
# pd_capital_dependent
# lt_internal_ar
# lt_loan_ar
# other_lt_ar
# pvsn_doubt_lt_ar
# fixed_assets
# tgbl_fixed_assets
# tgbl_fixed_assets_cost
# tgbl_fixed_assets_depre
# fin_leases
# fin_leases_cost
# fin_leases_cost_depre
# intgbl_fixed_assets
# intgbl_fixed_assets_cost
# intgbl_fixed_assets_amor
# invmts_properties
# invmts_properties_cost
# invmts_properties_depre
# lt_assets_in_progress
# lt_wip
# construction_wip
# lt_invmts
# invmts_subs
# invmts_assocs
# invmts_other_entities
# pvsn_lt_invmts
# hld_mature_invmts_lt
# other_lt_invmts
# other_lt_assets_all
# lt_prepaid_exp
# deferred_tax_assets
# lt_tools_materials
# other_lt_assets
# goodwill
# total_assets
# N/A
# liabilities
# current_liabilities
# st_trade_ap
# st_adv_customers
# stat_obligations
# ap_employees
# st_accrued_exp
# st_internal_ap
# construction_cntrct_ap
# st_unearned_rev
# st_other_ap
# st_loan_finlease_ap
# st_pvsn
# bonus_wf_fund
# price_stabili_fund
# gov_bonds_hld_purchase
# noncurrent_liabilities
# lt_trade_ap
# lt_adv_customers
# lt_accrued_exp
# lt_internal_ap_capital
# lt_internal_ap
# lt_unearned_rev
# other_lt_liabilities
# st_loan_finlease_ap
# convert_bonds_liabilities
# pref_shares_liabilities
# deferred_tax_liabilities
# lt_pvsn
# sci_tech_dev_fund
# pvsn_sever_allowances
# owners_equity
# capital
# contrib_charter_capital
# shares_vote_rights
# pref_shares_equity
# share_premium
# convertible_bonds_equity
# other_owner_capital
# treasury_shares
# asset_reval_reserve
# forex_diff_reserve
# invmt_dev_fund
# enterprise_reorg_supp_fund
# other_funds_equity
# undis_earnings_losses
# undis_earnings_losses_prior
# undis_earnings_losses_current
# fund_capex
# non_ctrl_interests
# fin_reserves
# other_funds_all
# subsidized_fund
# fund_fixed_assets_in_use
# minority_interest
# total_liabilities_equity
# N/A
# current_assets
# cash_cash_equiv
# cash
# cash_equiv
# st_invmts
# hld_trading_secs_st
# pvsn_hld_trading_secs
# hld_mature_invmts
# current_ar
# st_trade_ar
# st_adv_suppliers
# st_internal_ar
# construction_cntrct_ar
# st_loan_ar
# other_st_ar
# pvsn_doubt_st_ar
# st_wait_resolution
# inventories_all
# inventories
# pvsn_obsolete_inventories
# other_current_assets_all
# st_prepaid_exp
# vat_deductible
# from_state_tax_ar
# gov_bonds_hld_resale
# other_current_assets
# noncurrent_assets
# lt_ar
# lt_trade_ar
# lt_adv_suppliers
# pd_capital_dependent
# lt_internal_ar
# lt_loan_ar
# other_lt_ar
# pvsn_doubt_lt_ar
# fixed_assets
# tgbl_fixed_assets
# tgbl_fixed_assets_cost
# tgbl_fixed_assets_depre
# fin_leases
# fin_leases_cost
# fin_leases_cost_depre
# intgbl_fixed_assets
# intgbl_fixed_assets_cost
# intgbl_fixed_assets_amor
# invmts_properties
# invmts_properties_cost
# invmts_properties_depre
# lt_assets_in_progress
# lt_wip
# construction_wip
# lt_invmts
# invmts_subs
# invmts_assocs
# invmts_other_entities
# pvsn_lt_invmts
# hld_mature_invmts_lt
# other_lt_invmts
# other_lt_assets_all
# lt_prepaid_exp
# deferred_tax_assets
# lt_tools_materials
# other_lt_assets
# goodwill
# total_assets
# N/A
# liabilities
# current_liabilities
# st_trade_ap
# st_adv_customers
# stat_obligations
# ap_employees
# st_accrued_exp
# st_internal_ap
# construction_cntrct_ap
# st_unearned_rev
# st_other_ap
# st_loan_finlease_ap
# st_pvsn
# bonus_wf_fund
# price_stabili_fund
# gov_bonds_hld_purchase
# noncurrent_liabilities
# lt_trade_ap
# lt_adv_customers
# lt_accrued_exp
# lt_internal_ap_capital
# lt_internal_ap
# lt_unearned_rev
# other_lt_liabilities
# st_loan_finlease_ap
# convert_bonds_liabilities
# pref_shares_liabilities
# deferred_tax_liabilities
# lt_pvsn
# sci_tech_dev_fund
# pvsn_sever_allowances
# owners_equity
# capital
# contrib_charter_capital
# shares_vote_rights
# pref_shares_equity
# share_premium
# convertible_bonds_equity
# other_owner_capital
# treasury_shares
# asset_reval_reserve
# forex_diff_reserve
# invmt_dev_fund
# enterprise_reorg_supp_fund
# other_funds_equity
# undis_earnings_losses
# undis_earnings_losses_prior
# undis_earnings_losses_current
# fund_capex
# non_ctrl_interests
# fin_reserves
# other_funds_all
# subsidized_fund
# fund_fixed_assets_in_use
# minority_interest
# total_liabilities_equity
# N/A
# current_assets
# cash_cash_equiv
# cash
# cash_equiv
# st_invmts
# hld_trading_secs_st
# pvsn_hld_trading_secs
# hld_mature_invmts
# current_ar
# st_trade_ar
# st_adv_suppliers
# st_internal_ar
# construction_cntrct_ar
# st_loan_ar
# other_st_ar
# pvsn_doubt_st_ar
# st_wait_resolution
# inventories_all
# inventories
# pvsn_obsolete_inventories
# other_current_assets_all
# st_prepaid_exp
# vat_deductible
# from_state_tax_ar
# gov_bonds_hld_resale
# other_current_assets
# noncurrent_assets
# lt_ar
# lt_trade_ar
# lt_adv_suppliers
# pd_capital_dependent
# lt_internal_ar
# lt_loan_ar
# other_lt_ar
# pvsn_doubt_lt_ar
# fixed_assets
# tgbl_fixed_assets
# tgbl_fixed_assets_cost
# tgbl_fixed_assets_depre
# fin_leases
# fin_leases_cost
# fin_leases_cost_depre
# intgbl_fixed_assets
# intgbl_fixed_assets_cost
# intgbl_fixed_assets_amor
# invmts_properties
# invmts_properties_cost
# invmts_properties_depre
# lt_assets_in_progress
# lt_wip
# construction_wip
# lt_invmts
# invmts_subs
# invmts_assocs
# invmts_other_entities
# pvsn_lt_invmts
# hld_mature_invmts_lt
# other_lt_invmts
# other_lt_assets_all
# lt_prepaid_exp
# deferred_tax_assets
# lt_tools_materials
# other_lt_assets
# goodwill
# total_assets
# N/A
# liabilities
# current_liabilities
# st_trade_ap
# st_adv_customers
# stat_obligations
# ap_employees
# st_accrued_exp
# st_internal_ap
# construction_cntrct_ap
# st_unearned_rev
# st_other_ap
# st_loan_finlease_ap
# st_pvsn
# bonus_wf_fund
# price_stabili_fund
# gov_bonds_hld_purchase
# noncurrent_liabilities
# lt_trade_ap
# lt_adv_customers
# lt_accrued_exp
# lt_internal_ap_capital
# lt_internal_ap
# lt_unearned_rev
# other_lt_liabilities
# st_loan_finlease_ap
# convert_bonds_liabilities
# pref_shares_liabilities
# deferred_tax_liabilities
# lt_pvsn
# sci_tech_dev_fund
# pvsn_sever_allowances
# owners_equity
# capital
# contrib_charter_capital
# shares_vote_rights
# pref_shares_equity
# share_premium
# convertible_bonds_equity
# other_owner_capital
# treasury_shares
# asset_reval_reserve
# forex_diff_reserve
# invmt_dev_fund
# enterprise_reorg_supp_fund
# other_funds_equity
# undis_earnings_losses
# undis_earnings_losses_prior
# undis_earnings_losses_current
# fund_capex
# non_ctrl_interests
# fin_reserves
# other_funds_all
# subsidized_fund
# fund_fixed_assets_in_use
# minority_interest
# total_liabilities_equity
# N/A
# current_assets
# cash_cash_equiv
# cash
# cash_equiv
# st_invmts
# hld_trading_secs_st
# pvsn_hld_trading_secs
# hld_mature_invmts
# current_ar
# st_trade_ar
# st_adv_suppliers
# st_internal_ar
# construction_cntrct_ar
# st_loan_ar
# other_st_ar
# pvsn_doubt_st_ar
# st_wait_resolution
# inventories_all
# inventories
# pvsn_obsolete_inventories
# other_current_assets_all
# st_prepaid_exp
# vat_deductible
# from_state_tax_ar
# gov_bonds_hld_resale
# other_current_assets
# noncurrent_assets
# lt_ar
# lt_trade_ar
# lt_adv_suppliers
# pd_capital_dependent
# lt_internal_ar
# lt_loan_ar
# other_lt_ar
# pvsn_doubt_lt_ar
# fixed_assets
# tgbl_fixed_assets
# tgbl_fixed_assets_cost
# tgbl_fixed_assets_depre
# fin_leases
# fin_leases_cost
# fin_leases_cost_depre
# intgbl_fixed_assets
# intgbl_fixed_assets_cost
# intgbl_fixed_assets_amor
# invmts_properties
# invmts_properties_cost
# invmts_properties_depre
# lt_assets_in_progress
# lt_wip
# construction_wip
# lt_invmts
# invmts_subs
# invmts_assocs
# invmts_other_entities
# pvsn_lt_invmts
# hld_mature_invmts_lt
# other_lt_invmts
# other_lt_assets_all
# lt_prepaid_exp
# deferred_tax_assets
# lt_tools_materials
# other_lt_assets
# goodwill
# total_assets
# N/A
# liabilities
# current_liabilities
# st_trade_ap
# st_adv_customers
# stat_obligations
# ap_employees
# st_accrued_exp
# st_internal_ap
# construction_cntrct_ap
# st_unearned_rev
# st_other_ap
# st_loan_finlease_ap
# st_pvsn
# bonus_wf_fund
# price_stabili_fund
# gov_bonds_hld_purchase
# noncurrent_liabilities
# lt_trade_ap
# lt_adv_customers
# lt_accrued_exp
# lt_internal_ap_capital
# lt_internal_ap
# lt_unearned_rev
# other_lt_liabilities
# st_loan_finlease_ap
# convert_bonds_liabilities
# pref_shares_liabilities
# deferred_tax_liabilities
# lt_pvsn
# sci_tech_dev_fund
# pvsn_sever_allowances
# owners_equity
# capital
# contrib_charter_capital
# shares_vote_rights
# pref_shares_equity
# share_premium
# convertible_bonds_equity
# other_owner_capital
# treasury_shares
# asset_reval_reserve
# forex_diff_reserve
# invmt_dev_fund
# enterprise_reorg_supp_fund
# other_funds_equity
# undis_earnings_losses
# undis_earnings_losses_prior
# undis_earnings_losses_current
# fund_capex
# non_ctrl_interests
# fin_reserves
# other_funds_all
# subsidized_fund
# fund_fixed_assets_in_use
# minority_interest
# total_liabilities_equity
# N/A
# current_assets
# cash_cash_equiv
# cash
# cash_equiv
# st_invmts
# hld_trading_secs_st
# pvsn_hld_trading_secs
# hld_mature_invmts
# current_ar
# st_trade_ar
# st_adv_suppliers
# st_internal_ar
# construction_cntrct_ar
# st_loan_ar
# other_st_ar
# pvsn_doubt_st_ar
# st_wait_resolution
# inventories_all
# inventories
# pvsn_obsolete_inventories
# other_current_assets_all
# st_prepaid_exp
# vat_deductible
# from_state_tax_ar
# gov_bonds_hld_resale
# other_current_assets
# noncurrent_assets
# lt_ar
# lt_trade_ar
# lt_adv_suppliers
# pd_capital_dependent
# lt_internal_ar
# lt_loan_ar
# other_lt_ar
# pvsn_doubt_lt_ar
# fixed_assets
# tgbl_fixed_assets
# tgbl_fixed_assets_cost
# tgbl_fixed_assets_depre
# fin_leases
# fin_leases_cost
# fin_leases_cost_depre
# intgbl_fixed_assets
# intgbl_fixed_assets_cost
# intgbl_fixed_assets_amor
# invmts_properties
# invmts_properties_cost
# invmts_properties_depre
# lt_assets_in_progress
# lt_wip
# construction_wip
# lt_invmts
# invmts_subs
# invmts_assocs
# invmts_other_entities
# pvsn_lt_invmts
# hld_mature_invmts_lt
# other_lt_invmts
# other_lt_assets_all
# lt_prepaid_exp
# deferred_tax_assets
# lt_tools_materials
# other_lt_assets
# goodwill
# total_assets
# N/A
# liabilities
# current_liabilities
# st_trade_ap
# st_adv_customers
# stat_obligations
# ap_employees
# st_accrued_exp
# st_internal_ap
# construction_cntrct_ap
# st_unearned_rev
# st_other_ap
# st_loan_finlease_ap
# st_pvsn
# bonus_wf_fund
# price_stabili_fund
# gov_bonds_hld_purchase
# noncurrent_liabilities
# lt_trade_ap
# lt_adv_customers
# lt_accrued_exp
# lt_internal_ap_capital
# lt_internal_ap
# lt_unearned_rev
# other_lt_liabilities
# st_loan_finlease_ap
# convert_bonds_liabilities
# pref_shares_liabilities
# deferred_tax_liabilities
# lt_pvsn
# sci_tech_dev_fund
# pvsn_sever_allowances
# owners_equity
# capital
# contrib_charter_capital
# shares_vote_rights
# pref_shares_equity
# share_premium
# convertible_bonds_equity
# other_owner_capital
# treasury_shares
# asset_reval_reserve
# forex_diff_reserve
# invmt_dev_fund
# enterprise_reorg_supp_fund
# other_funds_equity
# undis_earnings_losses
# undis_earnings_losses_prior
# undis_earnings_losses_current
# fund_capex
# non_ctrl_interests
# fin_reserves
# other_funds_all
# subsidized_fund
# fund_fixed_assets_in_use
# minority_interest
# total_liabilities_equity
# N/A
# current_assets
# cash_cash_equiv
# cash
# cash_equiv
# st_invmts
# hld_trading_secs_st
# pvsn_hld_trading_secs
# hld_mature_invmts
# current_ar
# st_trade_ar
# st_adv_suppliers
# st_internal_ar
# construction_cntrct_ar
# st_loan_ar
# other_st_ar
# pvsn_doubt_st_ar
# st_wait_resolution
# inventories_all
# inventories
# pvsn_obsolete_inventories
# other_current_assets_all
# st_prepaid_exp
# vat_deductible
# from_state_tax_ar
# gov_bonds_hld_resale
# other_current_assets
# noncurrent_assets
# lt_ar
# lt_trade_ar
# lt_adv_suppliers
# pd_capital_dependent
# lt_internal_ar
# lt_loan_ar
# other_lt_ar
# pvsn_doubt_lt_ar
# fixed_assets
# tgbl_fixed_assets
# tgbl_fixed_assets_cost
# tgbl_fixed_assets_depre
# fin_leases
# fin_leases_cost
# fin_leases_cost_depre
# intgbl_fixed_assets
# intgbl_fixed_assets_cost
# intgbl_fixed_assets_amor
# invmts_properties
# invmts_properties_cost
# invmts_properties_depre
# lt_assets_in_progress
# lt_wip
# construction_wip
# lt_invmts
# invmts_subs
# invmts_assocs
# invmts_other_entities
# pvsn_lt_invmts
# hld_mature_invmts_lt
# other_lt_invmts
# other_lt_assets_all
# lt_prepaid_exp
# deferred_tax_assets
# lt_tools_materials
# other_lt_assets
# goodwill
# total_assets
# N/A
# liabilities
# current_liabilities
# st_trade_ap
# st_adv_customers
# stat_obligations
# ap_employees
# st_accrued_exp
# st_internal_ap
# construction_cntrct_ap
# st_unearned_rev
# st_other_ap
# st_loan_finlease_ap
# st_pvsn
# bonus_wf_fund
# price_stabili_fund
# gov_bonds_hld_purchase
# noncurrent_liabilities
# lt_trade_ap
# lt_adv_customers
# lt_accrued_exp
# lt_internal_ap_capital
# lt_internal_ap
# lt_unearned_rev
# other_lt_liabilities
# st_loan_finlease_ap
# convert_bonds_liabilities
# pref_shares_liabilities
# deferred_tax_liabilities
# lt_pvsn
# sci_tech_dev_fund
# pvsn_sever_allowances
# owners_equity
# capital
# contrib_charter_capital
# shares_vote_rights
# pref_shares_equity
# share_premium
# convertible_bonds_equity
# other_owner_capital
# treasury_shares
# asset_reval_reserve
# forex_diff_reserve
# invmt_dev_fund
# enterprise_reorg_supp_fund
# other_funds_equity
# undis_earnings_losses
# undis_earnings_losses_prior
# undis_earnings_losses_current
# fund_capex
# non_ctrl_interests
# fin_reserves
# other_funds_all
# subsidized_fund
# fund_fixed_assets_in_use
# minority_interest
# total_liabilities_equity
# N/A
# current_assets
# cash_cash_equiv
# cash
# cash_equiv
# st_invmts
# hld_trading_secs_st
# pvsn_hld_trading_secs
# hld_mature_invmts
# current_ar
# st_trade_ar
# st_adv_suppliers
# st_internal_ar
# construction_cntrct_ar
# st_loan_ar
# other_st_ar
# pvsn_doubt_st_ar
# st_wait_resolution
# inventories_all
# inventories
# pvsn_obsolete_inventories
# other_current_assets_all
# st_prepaid_exp
# vat_deductible
# from_state_tax_ar
# gov_bonds_hld_resale
# other_current_assets
# noncurrent_assets
# lt_ar
# lt_trade_ar
# lt_adv_suppliers
# pd_capital_dependent
# lt_internal_ar
# lt_loan_ar
# other_lt_ar
# pvsn_doubt_lt_ar
# fixed_assets
# tgbl_fixed_assets
# tgbl_fixed_assets_cost
# tgbl_fixed_assets_depre
# fin_leases
# fin_leases_cost
# fin_leases_cost_depre
# intgbl_fixed_assets
# intgbl_fixed_assets_cost
# intgbl_fixed_assets_amor
# invmts_properties
# invmts_properties_cost
# invmts_properties_depre
# lt_assets_in_progress
# lt_wip
# construction_wip
# lt_invmts
# invmts_subs
# invmts_assocs
# invmts_other_entities
# pvsn_lt_invmts
# hld_mature_invmts_lt
# other_lt_invmts
# other_lt_assets_all
# lt_prepaid_exp
# deferred_tax_assets
# lt_tools_materials
# other_lt_assets
# goodwill
# total_assets
# N/A
# liabilities
# current_liabilities
# st_trade_ap
# st_adv_customers
# stat_obligations
# ap_employees
# st_accrued_exp
# st_internal_ap
# construction_cntrct_ap
# st_unearned_rev
# st_other_ap
# st_loan_finlease_ap
# st_pvsn
# bonus_wf_fund
# price_stabili_fund
# gov_bonds_hld_purchase
# noncurrent_liabilities
# lt_trade_ap
# lt_adv_customers
# lt_accrued_exp
# lt_internal_ap_capital
# lt_internal_ap
# lt_unearned_rev
# other_lt_liabilities
# st_loan_finlease_ap
# convert_bonds_liabilities
# pref_shares_liabilities
# deferred_tax_liabilities
# lt_pvsn
# sci_tech_dev_fund
# pvsn_sever_allowances
# owners_equity
# capital
# contrib_charter_capital
# shares_vote_rights
# pref_shares_equity
# share_premium
# convertible_bonds_equity
# other_owner_capital
# treasury_shares
# asset_reval_reserve
# forex_diff_reserve
# invmt_dev_fund
# enterprise_reorg_supp_fund
# other_funds_equity
# undis_earnings_losses
# undis_earnings_losses_prior
# undis_earnings_losses_current
# fund_capex
# non_ctrl_interests
# fin_reserves
# other_funds_all
# subsidized_fund
# fund_fixed_assets_in_use
# minority_interest
# total_liabilities_equity
# N/A
# current_assets
# cash_cash_equiv
# cash
# cash_equiv
# st_invmts
# hld_trading_secs_st
# pvsn_hld_trading_secs
# hld_mature_invmts
# current_ar
# st_trade_ar
# st_adv_suppliers
# st_internal_ar
# construction_cntrct_ar
# st_loan_ar
# other_st_ar
# pvsn_doubt_st_ar
# st_wait_resolution
# inventories_all
# inventories
# pvsn_obsolete_inventories
# other_current_assets_all
# st_prepaid_exp
# vat_deductible
# from_state_tax_ar
# gov_bonds_hld_resale
# other_current_assets
# noncurrent_assets
# lt_ar
# lt_trade_ar
# lt_adv_suppliers
# pd_capital_dependent
# lt_internal_ar
# lt_loan_ar
# other_lt_ar
# pvsn_doubt_lt_ar
# fixed_assets
# tgbl_fixed_assets
# tgbl_fixed_assets_cost
# tgbl_fixed_assets_depre
# fin_leases
# fin_leases_cost
# fin_leases_cost_depre
# intgbl_fixed_assets
# intgbl_fixed_assets_cost
# intgbl_fixed_assets_amor
# invmts_properties
# invmts_properties_cost
# invmts_properties_depre
# lt_assets_in_progress
# lt_wip
# construction_wip
# lt_invmts
# invmts_subs
# invmts_assocs
# invmts_other_entities
# pvsn_lt_invmts
# hld_mature_invmts_lt
# other_lt_invmts
# other_lt_assets_all
# lt_prepaid_exp
# deferred_tax_assets
# lt_tools_materials
# other_lt_assets
# goodwill
# total_assets
# N/A
# liabilities
# current_liabilities
# st_trade_ap
# st_adv_customers
# stat_obligations
# ap_employees
# st_accrued_exp
# st_internal_ap
# construction_cntrct_ap
# st_unearned_rev
# st_other_ap
# st_loan_finlease_ap
# st_pvsn
# bonus_wf_fund
# price_stabili_fund
# gov_bonds_hld_purchase
# noncurrent_liabilities
# lt_trade_ap
# lt_adv_customers
# lt_accrued_exp
# lt_internal_ap_capital
# lt_internal_ap
# lt_unearned_rev
# other_lt_liabilities
# st_loan_finlease_ap
# convert_bonds_liabilities
# pref_shares_liabilities
# deferred_tax_liabilities
# lt_pvsn
# sci_tech_dev_fund
# pvsn_sever_allowances
# owners_equity
# capital
# contrib_charter_capital
# shares_vote_rights
# pref_shares_equity
# share_premium
# convertible_bonds_equity
# other_owner_capital
# treasury_shares
# asset_reval_reserve
# forex_diff_reserve
# invmt_dev_fund
# enterprise_reorg_supp_fund
# other_funds_equity
# undis_earnings_losses
# undis_earnings_losses_prior
# undis_earnings_losses_current
# fund_capex
# non_ctrl_interests
# fin_reserves
# other_funds_all
# subsidized_fund
# fund_fixed_assets_in_use
# minority_interest
# total_liabilities_equity
