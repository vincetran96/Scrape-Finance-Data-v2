# %%
import pandas as pd
import json
import glob

# %%
# bs_all_accs = set()
report_types_bs_is = {"CDKT":{},
                        "KQKD":{}
                     }
report_types_cf = {"LC": set()
                    }

# %%
for report_type, report_all_accounts in report_types_bs_is.items():
    for file in glob.glob(f'localData/financeInfo/*{report_type}_Annual*.json'):
        with open(file, 'r') as jsonfile:
            j = json.load(jsonfile)
            for report_fullname, report_content in j[1].items():
                for acc in report_content:
                    ### Each account with its ID, and details as [name, level, parent]
                    n_strip = acc['NameEn'].strip()
                    n_lower = n_strip.lower()
                    acc_id = acc['ReportNormID']
                    acc_details = [n_lower, acc['Levels'], acc['ParentReportNormID']]
                    if acc_id not in report_all_accounts.keys():
                        report_all_accounts[acc_id] = [acc_details]
                    else:
                        ### Check if the account is in the level list
                        if acc_details not in report_all_accounts[acc_id]:
                            report_all_accounts[acc_id].append(acc_details)
                        
    report_all_accounts = dict(sorted(report_all_accounts.items()))
    with open(f'schema/{report_type}_all_accounts.json', 'w') as writefile:
        json.dump(report_all_accounts, writefile, ensure_ascii=False, indent=4)

# %%
for k, v in report_types_bs_is['CDKT'].items():
    print(v[0][0])

# print(report_types_bs_is['CDKT'])
# Out:
# assets
# a. short-term assets
# i. cash and cash equivalents
# 1. cash
# 2. cash equivalents
# ii.  short-term financial investments
# 1. available for sale securities
# 2. provision for diminution in value of available for sale securities (*)
# 3. held to maturity investments
# iii. short-term receivables
# 1. short-term trade accounts receivable
# 2. short-term prepayments to suppliers
# 3. short-term inter-company receivables
# 4. construction contract progress receipts due from customers
# 5. short-term loan receivables
# 6. other short-term receivables
# 7. provision for short-term doubtful debts (*)
# 8. assets awaiting resolution
# iv. inventories
# 1. inventories
# 2. provision for decline in value of inventories
# v. other short-term assets
# 1. short-term prepayments
# 2. value added tax to be reclaimed
# 3. taxes and other receivables from state authorities
# 4. government bonds
# 5. other short-term assets
# b. long-term assets
# i. long-term receivables
# 1. long-term trade receivables
# 2. long-term prepayments to suppliers
# 3. capital at inter-company
# 4. long-term inter-company receivables
# 5. long-term loan receivables
# 6. other long-term receivables
# 7. provision for long-term doubtful debts
# ii. fixed assets
# 1. tangible fixed assets
# - cost
# - accumulated depreciation
# 2. financial leased fixed assets
# - cost
# - accumulated depreciation
# 3. intangible fixed assets
# - cost
# - accumulated depreciation
# iii. investment properties
# - cost
# - accumulated depreciation
# iv. long-term assets in progress
# 1. long-term production in progress
# 2. construction in progress
# v. long-term financial investments
# 1. investments in subsidiaries
# 2. investments in associates, joint-ventures
# 3. investments in other entities
# 4. provision for diminution in value of long-term investments
# 5. held to maturity investments
# 6. other long-term investments
# vi. other long-term assets
# 1. long-term prepayments
# 2. deferred income tax assets
# 3. long-term equipment, supplies, spare parts
# 4. other long-term assets
# vii. goodwill
# total assets
# owner's equity
# a.  liabilities
# i. short -term liabilities
# 1.  short-term trade accounts payable
# 2. short-term advances from customers
# 3. taxes and other payables to state authorities
# 4. payable to employees
# 5. short-term acrrued expenses
# 6. short-term inter-company payables
# 7. construction contract progress payments due to suppliers
# 8. short-term unearned revenue
# 9. other short-term payables
# 10. short-term borrowings and financial leases
# 11. provision for short-term liabilities
# 12.. bonus and welfare fund
# 13. price stabilization fund
# 14. government bonds
# ii. long-term liabilities
# 1. long-term trade payables
# 2. long-term advances from customers
# 3. long-term acrrued expenses
# 4. inter-company payables on business capital
# 5. long-term inter-company payables
# 6. long-term unearned revenue
# 7. other long-term liabilities
# 8. long-term borrowings and financial leases
# 9. convertible bonds
# 10. preferred stock (debts)
# 11. deferred income tax liabilities
# 12. provision for long-term liabilities
# 13. fund for technology development
# 14. provision for severance allowances
# b. owner's equity
# i. owner's equity
# 1. owner's capital
# - common stock with voting right
# - preferred stock
# 2. share premium
# 3. convertible bond option
# 4. other capital of owners
# 5. treasury shares
# 6. assets revaluation differences
# 7. foreign exchange differences
# 8. investment and development fund
# 9. fund to support corporate restructuring
# 10. other funds from owner's equity
# 11. undistributed earnings after tax
# - accumulated retained earning at the end of the previous period
# - undistributed earnings in this period
# 12. reserves for investment in construction
# 13. minority's interest
# 14. financial reserves
# ii. other resources and funds
# 1. subsidized not-for-profit funds
# 2. funds invested in fixed assets
# c. minority's interest
# total owner's equity and liabilities
# assets
# i. cash, gold and silver, precious stones
# ii. balances with the state bank of vietnam
# iii. placements at and loans to other credit institutions
# 1. placements at other credit institutions
# 2. loans to other credit institutions
# 3. provisions for losses and risks
# iv. trading securities
# 1. trading securities
# 2. provisions for diminution in value of trading securities
# v. derivatives and other financial assets
# vi. loans, advances and finance leases to customers
# 1. loans, advances and finance leases to customers
# 2. provisions for losses on loans, advances and finance leases to customers
# vii. debt purchased
# 1. debt purchased
# 2. provision for debt purchased
# vii. investment securities
# 1. available-for-sales securities
# 2. held to maturity securities
# 3. provisions for diminution in value of investment securities
# viii. capital contribution and other long-term investments
# 1. investments in subsidiaries
# 2.  investments in associates, joint-ventures
# 3. other long-term investments
# 4. provision for diminution in value of long-term investments
# ix.  fixed assets
# 1. tangible fixed assets
# a. cost
# b. accumulated depreciation
# 2. finance leased fixed assets
# a. cost
# b. accumulated depreciation
# 3. intangible fixed assets
# a. cost
# b. accumulated depreciation
# x. investment properties
# a. cost
# b. accumulated depreciation
# xi. other assets
# 1.  accounts receivables
# 2. interest and fee receivables
# 3. deferred income tax assets
# 4. other assets
# - of which: goodwill
# 5. provisions for risks in other assets
# total assets
# b. liabilities and owner's equity
# i. due to government and borrowings from the state bank of vietnam
# ii. placements and borrowings from other credit institutions
# 1. placements from other credit institutions
# 2. borrowings from other credit institutions
# iii. deposits from customers
# iv. derivatives and other financial liabilities
# v. funds received from government and institutions, investments on behalf of investors, syndicated loans of the bank's risks
# vi. valuable papers (e.g. bonds, cds..)
# vii. other liabilities
# 1. interest and fee payables
# 2. deferred income tax liabilities
# 3. other liabilities
# 4. provisions for contingent liabilities and off-balance sheet commitments
# total liabilities
# viii. capital and reserves
# 1. capital
# a. charter capital
# b. reserves for investments in construction
# c. share premium
# d. treasury shares
# e. preferred stock
# g. other capital
# 2. reserves
# 3. foreign exchange differences
# 4. assets revaluation differences
# 5. undistributed earnings after tax/accumulated loss
# 6. minority's interest
# ix. minority interest
# total liabilities and owner's equity
# assets
# a. short-term assets
# i. cash and cash equivalents
# 1. cash
# 2. cash equivalents
# ii.   short-term investments
# 1. short-term investments
# 2. provision for diminution in value of short-term investments
# 3. held to maturity investments
# iii. short-term receivables
# 1. trade accounts receivable
# 1.1. insurance contract receivables
# 12. other receivables of customers
# 2. prepayments to suppliers
# 3. short-term inter-company receivables
# 4. short-term loan receivables
# 5. other receivables
# 6. provision for short-term doubtful debts
# 7. assets waiting for resolution
# 4. construction contract progress receipts due from customers
# iv. inventories
# 1. inventories
# 2. provision for decline in value of inventories
# v. other short-term assets
# 1. short-term prepayments
# 1.1. unallocated commissions expenses
# 1.2. other short-term prepaid expenses
# 2. value added tax to be reclaimed
# 3. taxes and other receivables from state authorities
# 4. payables for government bond trading activities
# 5. other short-term assets
# viii. reinsurance assets
# 1. reinsurance assets from unearned premium reserves
# 2. reinsurance assets from claim reserves
# b. long-term assets
# i. long-term receivables
# 1. long-term trade receivables
# 2. long-term prepayments to suppliers
# 2. capital at inter-company
# 3. long-term inter-company receivables
# 5. long-term loan receivables
# 4. other long-term receivables
# 3. long-term margin deposits
# 6.2. other long-term receivables
# 5. provision for long-term doubtful debts
# ii. fixed assets
# 1. tangible fixed assets
# - cost
# - accumulated depreciation
# 2. financial leased fixed assets
# - cost
# - accumulated depreciation
# 3. intangible fixed assets
# - cost
# - accumulated depreciation
# iii. investment properties
# - cost
# - accumulated depreciation
# iv. long-term assets in progress
# 4. construction in progress
# iv. long-term investments
# 1. investments in subsidiaries
# 2. investments in associates, joint-ventures
# 3. investments in other entities
# 4. provision for diminution in value of long-term investments
# 5. held to maturity investments
# 3. other long-term investments
# vi. other long-term assets
# 1. long-term prepayments
# 2. deferred income tax assets
# 3. long-term equipment, supplies, spare parts
# 4. other long-term assets
# v. goodwill
# total assets
# owner's equity
# a.  liabilities
# i. short -term liabilities
# 1. short-term borrowings
# 2. trade accounts payable
# 2.1. insurance contract payable
# 2.2. other payables to suppliers
# 3. advances from customers
# 4. taxes and other payables to state authorities
# 5. payable to employees
# 6. accrued expenses
# 7. inter-company payables
# 9. other payables
# 9. unearned commission revenues
# 10. provision for short-term liabilities
# 11. bonus and welfare fund
# 12. payables for government bond trading activities
# iii. reserves
# 1. unearned premium reserve
# 3. claim reserve
# 4. catastrophe reserve
# 2. mathematical reserve
# 5. dividend reserve
# 6. equalization reserve
# 14. short-term unearned revenue
# 8. construction contract progress payments due to suppliers
# ii. long-term liabilities
# 1. long-term trade payables
# 2. long-term inter-company payables
# 3. other long-term liabilities
# 4. long-term borrowings
# 5. deferred income tax liabilities
# 6. provision for severance allowances
# 7. provision for long-term liabilities
# 8. unearned revenue
# 9. fund for technology development
# b. owner's equity
# i. owner's equity
# 1. capital from owners
# - common stock with voting right
# - preferred stock
# 2. share premium
# 3. other capital of owners
# 4. treasury shares
# 5. assets revaluation differences
# 6. foreign exchange differences
# 7. investment and development fund
# 8. financial reserves
# 9. compulsory reserves
# 10. other reserves
# 11. undistributed earnings after tax
# - accumulated retained earning at the end of the previous period
# - undistributed earnings in this period
# 12. minority's interest
# 12. reserves for investment in construction
# 13. fund to support corporate restructuring
# ii. budget resources and other funds
# 1. subsidized not-for-profit funds
# 2. funds invested in fixed assets
# c. minority interests
# total owner's equity and liabilities
# assets
# a. short-term assets
# short-term financial assets
# i. cash and cash equivalents
# 1. cash
# 2. cash equivalents
# ii.   short-term investments
# 1. short-term investments
# 2. short-term investments of trust investors
# 3. provision for diminution in value of short-term investments
# 2. financial assets at fair value through profit or loss (fvtpl)
# 3. held to maturity investments (htm)
# 4. loans
# 5. available-for-sale financial assets (afs)
# 6. provisions for impairment loss of financial assets and mortgages
# iii. short-term receivables
# 7.1. receivables from disposal of financial assets
# 7.2. receivables and accruals from dividends and interest income
# 7.2.1. due dividend and interest receivables
# in which: doubtful receivables of dividends, interest to date of receipt but not yet received
# 7.2.2. undue dividend and interest receivables
# 2. prepayments to suppliers
# 9. service related receivable
# 4. receivables from securities trading activities
# 3. short -term inter-company receivables
# 11. receivables of securities trading error
# 5. other receivables
# 13. provision for doubtful debts
# 6. provision for short-term doubtful debts
# 1. trade accounts receivable
# iv. inventories
# 1. inventories
# 2. provision for decline in value of inventories
# v. other short-term assets
# 1. advances
# 2. office supplies, tools
# 1. short-term prepayments
# 4. pledged assets, mortgages, security deposits in short term
# 2. value added tax to be reclaimed
# 3. taxes and other receivables from state authorities
# 4. transaction buy backs governmental bond
# 5. other short-term assets
# 6. provision for other short-term assets
# b. long-term assets
# long-term financial assets
# i. long-term receivables
# 1. long-term trade receivables
# 2. capital at inter-company
# 3. long-term inter-company receivables
# 4. other long-term receivables
# 5. provision for long-term doubtful debts
# iv. long-term investments
# 2.1. held to maturity investments (htm)
# 1. investments in subsidiaries
# 2. investments in associates, joint-ventures
# 3. long-term securities investments
# - available-for-sale securities
# - held-to-maturity securities
# 4. other long-term investments
# 5. provision for diminution in value of long-term investments
# ii. fixed assets
# 1. tangible fixed assets
# - cost
# - accumulated depreciation
# evaluation tangible fixed assets accounting to fair value
# 2. financial leased fixed assets
# - cost
# - accumulated depreciation
# evaluation financial leased fixed assetss accounting to fair value
# 3. intangible fixed assets
# - cost
# - accumulated depreciation
# evaluation intangible fixed assets accounting to fair value
# iii. investment property
# - cost
# - accumulated depreciation
# evaluation investment property accounting to fair value
# 4. construction in progress
# vi. other long-term assets
# 1. pledged assets, mortgages, security deposits in long term
# 1. long-term prepayments
# 2. deferred income tax assets
# 3. payment for settlement assistance fund
# 4. other long-term assets
# v. goodwill
# provision for long-term assets
# total assets
# liabilities & owner's equity
# a.  liabilities
# i. short -term liabilities
# 1. short-term borrowings
# 1.1. short-term borrowings
# 1.2 short-term financial lease liabilities
# 2. short-term financial assets borrowings
# 3. short-term convertible bonds
# 4. short-term bonds
# 5. borrowings settlement assistance fund
# 9. payables to securities trading activities
# 7. payables to trading error of financial assets
# 2. trade accounts payable
# 3. advances from customers
# 4. taxes and other payables to state authorities
# 5. payable to employees
# 12. employee welfare payables
# 6. accrued expenses
# 7. inter-company payables
# 14. unearned revenue
# 16. short-term deposits, collateral received
# 8. other payables
# 10. payables for dividends, principal and interests on behalf of others
# 11. payables to securities issuing organizations
# 15. provision for short-term liabilities
# 13. payables for government bond trading activities
# 12. bonus and welfare fund
# ii. long-term liabilities
# 4. long-term borrowings
# 11. long-term borrowings
# 1.2 long-term financial lease liabilities
# 2. long-term financial lease borrowings
# 3. long-term convertible bonds
# 4. long-term bonds
# 1. long-term trade payables
# 6. advances from customers
# 7. accrued expenses
# 2. long-term inter-company payables
# 10. unearned revenue
# 10. long-term deposits, collateral received
# 3. other long-term liabilities
# 5. funds received from trust investors
# 7. provision for severance allowances
# 8. provision for long-term liabilities
# 9. provision for investor's damage claims
# 6. deferred income tax liabilities
# 11. fund for technology development
# b. owner's equity
# i. owner's equity
# 1. investment capital from owners
# 1. capital from owners
# common stock
# preferred stock
# 2. share premium
# 1.3 conversion options on convertible bonds
# 3. other capital of owners
# 4. treasury shares
# 5. assets revaluation differences
# 6. foreign exchange differences
# 4. supplementary capital reserve
# 7. investment and development fund
# 8. financial reserves
# 9. other funds from owner's equity
# 10. undistributed earnings after tax
# 7.1. realised profits
# 7.2. unrealised losses
# 11. reserves for investment in construction
# 12. fund to support corporate restructuring
# c. minority interest
# ii. budget resources and other funds
# 2. subsidized not-for-profit funds
# 3. funds invested in fixed assets
# total owner's equity and liabilities
# realised profits for investor
# 1. realised profits for investor in the year
